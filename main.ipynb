# %% [markdown]
# # Summary
#
# The KITTI Detection and Tracking Benchmarks contain copies of subsets of the Raw Data.
# The Detection Devkit includes `train_mapping.txt` and `train_rand.txt` files that map
# Detection Benchmark files to Raw Data drives, but this mapping covers only training
# examples.  The Tracking Devkit contains `seqmap` files that denote the number of
# frames in the Tracking Benchmark train and test sequences, but these `seqmap` files
# do not map back to the Raw Data.  Upon writing the KITTI authors, we discovered that
# the Detection and Tracking benchmarks use the same (or similar) splits, and moreover
# that the Benchmark <=> Raw Data mapping was not recorded when the Benchmark files
# were assembled.
#
# Below we reconstruct the Benchmark <=> Raw Data (Sync) mapping in order to:
#  * allow us to join Benchmark labels against the Raw Data.
#  * study the density of Benchmark labels.
#
# Detection Benchmark: http://www.cvlibs.net/datasets/kitti/eval_object.php?obj_benchmark=3d
# Tracking Benchmark: http://www.cvlibs.net/datasets/kitti/eval_tracking.php
# Raw Data: http://www.cvlibs.net/datasets/kitti/raw_data.php
# Detection Devkit: https://s3.eu-central-1.amazonaws.com/avg-kitti/devkit_object.zip
# Tracking Devkit: https://s3.eu-central-1.amazonaws.com/avg-kitti/devkit_tracking.zip
#
# ## Setup
#
# To run this notebook locally, start a Jupyter instance in the `oarphpy/full` environment:
#
# ```
# docker run \
#     --name=psegs-kitti-ext -it --net=host \
#     -v/:/outer_root -v `pwd`:/opt/psegs-kitti-ex -w /opt/psegs-kitti-ex \
#       oarphpy/full:0.0.4 jupyter notebook --allow-root
# ```
#
# Copies of assets that this notebook creates are included in the repo under the `assets` subdirectory.  You can run this notebook using those included assets.
#
# ### Recreating Assets: Download KITTI
#
# In your clone of this repo, copy of symlink the root directory of your KITTI data to `./kitti_root`.  In `./kitti_root`, we expect to find the zipfiles for the Benchmarks (see constants `OBJECT_BENCHMARK_FNAMES` and `TRACKING_BENCHMARK_FNAMES` below) as well as the Raw Sync data (zip files that look like `2011_09_26_drive_0017_sync.zip`).  You do **NOT** need to decompress the zip files.
#
# To download KITTI, you might consider using their [download script](http://www.cvlibs.net/download.php?file=raw_data_downloader.zip) or you might want to write a simple `wget`-based solution [as demonstrated in monodepth2](https://github.com/nianticlabs/monodepth2/blob/d1c5f03c38305cae4e68917e472d2f9d4eda0b98/README.md#-kitti-training-data).  Downloading the KITTI data requires explicit acceptance of their license, so we don't include here an automated download tool.

# %% [markdown]
# ## Configuration And Constants

# %%
import os

# Local path to all Benchmark and Raw Sync zipfiles downloaded from the aforementioned URLs.
# Unless you use pre-computed Achive DataFrame data, we'll be reading these files in parallel
# and computing file hashes of their contents.
# Read-only spinning-disk storage OK.  We won't decompress the zips on-disk.
KITTI_DATA_BASE_DIR = './kitti_root'

# We'll save (or re-read) Parquet-formatted Archive DataFrame data from this directory.
# TODO
ARCHIVE_DF_SAVE_DIR = './assets/'

BENCHMARK_DF_PATH = os.path.join(ARCHIVE_DF_SAVE_DIR, 'benchmark_df')
RAW_SYNC_DF_PATH = os.path.join(ARCHIVE_DF_SAVE_DIR, 'raw_sync_df')
  '2011_09_26_drive_0019', '2011_09_26_drive_0020', '2011_09_26_drive_0022', '2011_09_26_drive_0023', '2011_09_26_drive_0035', '2011_09_26_drive_0036', '2011_09_26_drive_0039', '2011_09_26_drive_0046', '2011_09_26_drive_0061', '2011_09_26_drive_0064', '2011_09_26_drive_0079', '2011_09_26_drive_0086', '2011_09_26_drive_0087',

  # Road category
  '2011_09_26_drive_0015', '2011_09_26_drive_0027', '2011_09_26_drive_0028', '2011_09_26_drive_0029', '2011_09_26_drive_0032', '2011_09_26_drive_0052', '2011_09_26_drive_0070',
)

# %% [markdown]
# ## Setup And Utils
#
# Declare until functions and create Spark session.  This cell is idempotent.

# %%
import glob
import os
import pprint

import numpy as np
import pandas as pd
from pyspark.sql import functions as F

from oarphpy import util
from oarphpy.spark import NBSpark
from oarphpy import spark as S

def to_archive_df(spark, archive_path, fname_whitelister=None):    
    
    def to_row(fw):
        # NB: we've tried decoding the image files using imagio and the mapping
        # of Benchmark <=> Raw Sync files remains the same.  Thus we'll just
        # use a binary hash (which works with velodyne files and is a bit
        # faster too)
        
        import hashlib
        digest = hashlib.sha1(fw.data).hexdigest()
                
        from pyspark.sql import Row
        return Row(filename=fw.name, digest=digest)

    fw_rdd = S.archive_rdd(spark, archive_path)
    if fname_whitelister:
        fw_rdd = fw_rdd.filter(lambda fw: fname_whitelister(fw.name))
    fw_rdd = fw_rdd.repartition(os.cpu_count())
    archive_df = spark.createDataFrame(fw_rdd.map(to_row))
    
    # Add the archive name
    archive_name = os.path.basename(archive_path)
    archive_df = archive_df.withColumn('archive_name', F.lit(archive_name))
    
    # Add the topic
    # E.g. 2011_09_28/2011_09_28_drive_0108_sync/oxts/data/0000000033.txt -> oxts
    #      2011_09_28/2011_09_28_drive_0108_sync/image_00/data/0000000023.png -> image_00
    topic_clause = F.when(archive_df.filename.like('%oxts%'), 'oxts')
    topic_clause = topic_clause.when(archive_df.filename.like('%velodyne%'), 'velodyne')
    for i in range(4):
        topic = 'image_0%s' % i
        
        # Convention used in Raw Sync and Tracking Benchmark
        key = '/image_0%s/' % i
        topic_clause = topic_clause.when(archive_df.filename.like('%' + key + '%'), topic)

        # Convention used in Benchmarks
        key = '/image_%s/' % i
        topic_clause = topic_clause.when(archive_df.filename.like('%' + key + '%'), topic)

        key = '/prev_%s/' % i
        topic_clause = topic_clause.when(archive_df.filename.like('%' + key + '%'), topic)
        
        
    topic_clause = topic_clause.otherwise('')
    archive_df = archive_df.withColumn('topic', topic_clause)
    return archive_df

def is_image_or_scan_or_oxt(path):
    return (
        path.endswith('.png') or
        path.endswith('.bin') or
        ('oxt' in path and path.endswith('.txt') and (not path.endswith('dataformat.txt'))))

spark = NBSpark.getOrCreate()

def show_query(q, max_rows=1000, truncate=False):
    spark.sql(q).show(max_rows, truncate=truncate)
# Out:
# 2020-03-04 20:59:41,880	oarph 42 : Using source root /usr/local/lib/python3.6/dist-packages/IPython/core
# 2020-03-04 20:59:41,881	oarph 42 : Using source root /usr/local/lib/python3.6/dist-packages/IPython
# 2020-03-04 20:59:41,919	oarph 42 : Generating egg to /tmp/tmp1i570uc__oarphpy_eggbuild ...
# 2020-03-04 20:59:42,126	oarph 42 : ... done.  Egg at /tmp/tmp1i570uc__oarphpy_eggbuild/core-0.0.0-py3.6.egg

# %% [markdown]
# ## Create Archive DataFrames
#
# Now we'll create the `benchmark_df` and `raw_data_df` tables used for our analysis. The process of computing the SHA-1 for all data files is expensive, so this job can take 4.5hrs to run on a 12-thread machine.  Thanks to the licensing of KITTI, we include pre-computed copies of the tables in the `assets` directory of this repo.  In the cells below, we'll use those assets if present or recompute them if necessary.

# %%
paths = glob.glob(os.path.join(KITTI_DATA_BASE_DIR, '*'))

# Compute the tables if necssary; save them to disk to make the data persistent for our analysis below.
if not os.path.exists(BENCHMARK_DF_PATH):
    benchmark_dfs = [
        to_archive_df(spark, path, fname_whitelister=is_image_or_scan_or_oxt)
        for path in paths
        if is_benchmark_zip(path)
    ]
    benchmark_df = S.union_dfs(*benchmark_dfs)
    benchmark_df.write.parquet(BENCHMARK_DF_PATH, compression='gzip')

if not os.path.exists(RAW_SYNC_DF_PATH):
    raw_data_dfs = [
        to_archive_df(spark, path, fname_whitelister=is_image_or_scan_or_oxt)
        for path in paths
        if is_raw_data_zip(path)
    ]
    raw_data_df = S.union_dfs(*raw_data_dfs)
    raw_data_df.write.parquet(RAW_SYNC_DF_PATH, compression='gzip')

# %%
# Read the tables, which we may have (re-)computed above.
benchmark_df = spark.read.parquet(BENCHMARK_DF_PATH).persist()
raw_data_df = spark.read.parquet(RAW_SYNC_DF_PATH).persist()
benchmark_df.createOrReplaceTempView('benchmark_df')
raw_data_df.createOrReplaceTempView('raw_data_df')

# %% [markdown]
# ### Sanity Check
# Do the tables have the expected data, broken down by topic?  Some observations:
#  * The Object Benchmark has 1005 Velodyne coverage, but the Tracking Benchmark is missing 4 Velodyne scans, and the Raw Sync data is missing 4 scans.
#  * The Object Benchmark preceding image sets (e.g. `data_object_prev_2.zip`) are missing 102 frames.  That's more than the number of `SEGMENTS_WITH_TRACKLETS`, but less than the number of Raw Sync segments overall.

# %%
print("Benchmarks")
show_query("""
    SELECT
        archive_name benchmark,
        topic,
        COUNT(*) num
    FROM benchmark_df
    GROUP BY benchmark, topic
    ORDER BY benchmark, topic
""")

print("Raw Sync")
show_query("""
    SELECT topic, COUNT(*) n
    FROM raw_data_df
    GROUP BY topic
    ORDER BY topic
""")

# Expected
# Benchmarks
# +--------------------------+--------+-----+
# |benchmark                 |topic   |num  |
# +--------------------------+--------+-----+
# |data_object_image_2.zip   |image_02|14999|
# |data_object_image_3.zip   |image_03|14999|
# |data_object_prev_2.zip    |image_02|44895|
# |data_object_prev_3.zip    |image_03|44895|
# |data_object_velodyne.zip  |velodyne|14999|
# |data_tracking_image_2.zip |image_02|19103|
# |data_tracking_image_3.zip |image_03|19103|
# |data_tracking_oxts.zip    |oxts    |50   |
# |data_tracking_velodyne.zip|velodyne|19099|
# +--------------------------+--------+-----+

# Raw Sync
# +--------+-----+
# |topic   |n    |
# +--------+-----+
# |image_00|47889|
# |image_01|47889|
# |image_02|47889|
# |image_03|47889|
# |oxts    |48040|
# |velodyne|47885|
# +--------+-----+
# Out:
# Benchmarks
# +--------------------------+--------+-----+
# |benchmark                 |topic   |num  |
# +--------------------------+--------+-----+
# |data_object_image_2.zip   |image_02|14999|
# |data_object_image_3.zip   |image_03|14999|
# |data_object_prev_2.zip    |image_02|44895|
# |data_object_prev_3.zip    |image_03|44895|
# |data_object_velodyne.zip  |velodyne|14999|
# |data_tracking_image_2.zip |image_02|19103|
# |data_tracking_image_3.zip |image_03|19103|
# |data_tracking_oxts.zip    |oxts    |50   |
# |data_tracking_velodyne.zip|velodyne|19099|
# +--------------------------+--------+-----+
#
# Raw Sync
# +--------+-----+
# |topic   |n    |
# +--------+-----+
# |image_00|47889|
# |image_01|47889|
# |image_02|47889|
# |image_03|47889|
# |oxts    |48040|
# |velodyne|47885|
# +--------+-----+

# %% [markdown]
# Are we missing any expected segments?

# %%
import itertools
raw_segs = set(r[0].replace('_sync.zip', '') for r in raw_data_df.select('archive_name').collect())
segs_overall = set(
    itertools.chain.from_iterable(
        v
        for k, v in KITTI_CATEGORY_TO_SEGMENTS.items()
        if k != 'calibration'))
print('Missing segments: %s' % (segs_overall - num_raw_segs))
# Out:
# Missing segments: set()

# %% [markdown]
# ### Do the Benchmarks and Raw Sync Segments have Duplicate Data?
#
# We want to ensure two things:
#  * No image/velodyne scan is repeated within each of the two Benchmarks and within the Raw Sync data.  We expect there to be some overlap between these three groups, but each group should be distinct.
#  * We don't have any duplicate files in `KITTI_DATA_BASE_DIR`.
#
# Thus the queries below should result in empty output.

# %%
show_query("""
    SELECT
        digest,
        COLLECT_LIST(filename),
        COUNT(*) n
    FROM benchmark_df
    WHERE archive_name = 'data_object_image_2.zip'
    GROUP BY digest
    HAVING n >= 2
""")
show_query("""
    SELECT
        digest,
        COLLECT_LIST(filename),
        COUNT(*) n
    FROM benchmark_df
    WHERE archive_name = 'data_tracking_image_2.zip'
    GROUP BY digest
    HAVING n >= 2
""")

show_query("""
    SELECT
        digest,
        COLLECT_LIST(archive_name),
        COLLECT_LIST(filename),
        COUNT(*) n
    FROM raw_data_df
    GROUP BY digest
    HAVING n >= 2
""")
# Out:
# +------+----------------------+---+
# |digest|collect_list(filename)|n  |
# +------+----------------------+---+
# +------+----------------------+---+
#
# +------+----------------------+---+
# |digest|collect_list(filename)|n  |
# +------+----------------------+---+
# +------+----------------------+---+
#
# +------+--------------------------+----------------------+---+
# |digest|collect_list(archive_name)|collect_list(filename)|n  |
# +------+--------------------------+----------------------+---+
# +------+--------------------------+----------------------+---+

# %% [markdown]
# ### Train/Test Splits
# Let's infer the split for all files to study the Benchmark / Raw Sync overlap.  We expect the Raw Sync to only include training data.

# %%
benchmark_df_with_split = benchmark_df.withColumn(
    'split',
    F.when(benchmark_df.filename.like('%train%'), 'train').when(
        benchmark_df.filename.like('%test%'), 'test').otherwise('unknown'))
benchmark_df_with_split.createOrReplaceTempView('benchmark_df_with_split')

raw_data_df_with_split = raw_data_df.withColumn('split', F.lit('raw'))
raw_data_df_with_split.createOrReplaceTempView('raw_data_df_with_split')

# %% [markdown]
# ### How do the Benchmarks and Raw Sync data compare?
# Here are our main results:
#  * **The `test` data in the Benchmarks is not available in the Raw Sync data release.**
#  * The train and test sets are distinct.  The sets have no overlapping data.  Therefore, exist Raw Data segments that have never been made public, and the `test` data was draw from those segments.  (If you email Professor Geiger, he has copies of the scripts used to create the Benchmarks, and the content of those scripts substantiates this finding).
#  * The Tracking and Object Benchmarks are drawn from partially overlapping sets of Raw Data segments.
#  * There is slightly more `test` than `train` data for both Benchmarks.
#
# The first result is the main warrant for this project.  Since the `test` Raw Sync segments are hidden, and since the `test` data is made available **exclusively** through the Benchmark zip files, researchers probably want to focus on the Benchmarks data release and ignore the Raw Sync data release.  Firstly, the Benchmark zips require less data to be downloaded.  Secondly, the Benchmarks define the `train` split; KITTI does not publish separately how to derive the `train` split from the public Raw Sync data made available.  Thirdly, if a researcher wants more training data today, they might look to a larger dataset like [NuScenes](https://www.nuscenes.org/), [Argoverse](https://www.argoverse.org/), or [Waymo Open Dataset](https://waymo.com/open/).  The extra Raw Sync data is certainly useful, but not as relevant today as when it was originally released in 2012.  Therefore, we aim to contribute two things in this project:
#  * We recover the Benchmark <-> Raw Sync data mapping that shows how the Benchmarks were derived from the Raw Data.
#  * The Benchmark data files contain all the sensor data, but not the timestamp data.  Using the mapping above, we recover the timestamp data.  This data allows us to make the KITTI Benchmarks compatible with `avsegs`.

# %%
show_query("""
    SELECT
        b.split AS split,
        b.archive_name benchmark,
        COUNT(DISTINCT r.digest) AS n_rdigest,
        COUNT(*) AS n
    FROM benchmark_df_with_split AS b FULL OUTER JOIN raw_data_df_with_split r ON b.digest = r.digest
    GROUP BY b.split, benchmark
    ORDER BY benchmark, b.split DESC
""")
# Out:
# +-----+--------------------------+---------+------+
# |split|benchmark                 |n_rdigest|n     |
# +-----+--------------------------+---------+------+
# |null |null                      |240646   |240646|
# |train|data_object_image_2.zip   |7481     |7481  |
# |test |data_object_image_2.zip   |0        |7518  |
# |train|data_object_image_3.zip   |7481     |7481  |
# |test |data_object_image_3.zip   |0        |7518  |
# |train|data_object_prev_2.zip    |13904    |22394 |
# |test |data_object_prev_2.zip    |0        |22501 |
# |train|data_object_prev_3.zip    |13904    |22394 |
# |test |data_object_prev_3.zip    |0        |22501 |
# |train|data_object_velodyne.zip  |7481     |7481  |
# |test |data_object_velodyne.zip  |0        |7518  |
# |train|data_tracking_image_2.zip |8008     |8008  |
# |test |data_tracking_image_2.zip |0        |11095 |
# |train|data_tracking_image_3.zip |8008     |8008  |
# |test |data_tracking_image_3.zip |0        |11095 |
# |train|data_tracking_oxts.zip    |0        |21    |
# |test |data_tracking_oxts.zip    |0        |29    |
# |train|data_tracking_velodyne.zip|8004     |8004  |
# |test |data_tracking_velodyne.zip|0        |11095 |
# +-----+--------------------------+---------+------+

# %% [markdown]
# ### How well does the labeled data cover the segments?
# We drill down a little further on the Benchmark <-> Raw Sync mapping and see that:
#  * The Tracking Benchmark contain fully-labeled segments.
#  * The Object Benchmark samples are *not taken uniformly at random*, likely in order to achieve a target number of examples of each class.
#  * Given the two points above, we can deduce that the Tracking Benchmark actually contains additional labels that could be useful to the Object Benchmark.

# %%
# Append a `category` column to the Raw Sync table to show the category of segment.
seg_cat_clause = F.when(raw_data_df.archive_name.like(''), '')
for category, segments in KITTI_CATEGORY_TO_SEGMENTS.items():
    for segment in segments:
        seg_cat_clause = seg_cat_clause.when(
            raw_data_df.archive_name.like('%' + segment + '%'),
            category)
seg_cat_clause = seg_cat_clause.otherwise('')
raw_data_df_with_cat = raw_data_df.withColumn('category', seg_cat_clause)
raw_data_df_with_cat.createOrReplaceTempView('raw_data_df_with_category')

show_query("""
    WITH
      bb AS (  
          SELECT
            IF(filename LIKE '%test%', 'test', 'train') AS split,
            digest,
            archive_name benchmark
          FROM benchmark_df
          WHERE topic = 'image_02'  ),

      segment_count AS (
          SELECT
            archive_name segment,
            FIRST(category) category,
            COUNT(*) n_frames
          FROM raw_data_df_with_category
          WHERE topic = 'image_02'
          GROUP BY archive_name  ),

      label_counts AS (
        SELECT
            r.archive_name segment,
            FIRST(r.category) category,
            bb.split split,
            bb.benchmark benchmark,
            COUNT(*) n
        FROM raw_data_df_with_category r INNER JOIN bb
          ON r.digest = bb.digest
        GROUP BY split, benchmark, segment )
    
    SELECT 
       l.split,
       l.benchmark,
       l.category,
       l.segment,
       l.n n_labeled,
       s.n_frames n_total,
       l.n / s.n_frames frac_labeled
    FROM 
      label_counts l, segment_count s
    WHERE l.segment = s.segment
    ORDER BY l.split, l.benchmark, frac_labeled DESC, l.segment
       
""")
# Out:
# +-----+-------------------------+-----------+------------------------------+---------+-------+--------------------+
# |split|benchmark                |category   |segment                       |n_labeled|n_total|frac_labeled        |
# +-----+-------------------------+-----------+------------------------------+---------+-------+--------------------+
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0014_sync.zip|235      |314    |0.7484076433121019  |
# |train|data_object_image_2.zip  |road       |2011_09_26_drive_0015_sync.zip|215      |297    |0.7239057239057239  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0056_sync.zip|197      |294    |0.6700680272108843  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0009_sync.zip|287      |447    |0.6420581655480985  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0095_sync.zip|166      |268    |0.6194029850746269  |
# |train|data_object_image_2.zip  |road       |2011_09_26_drive_0101_sync.zip|577      |936    |0.6164529914529915  |
# |train|data_object_image_2.zip  |city       |2011_09_28_drive_0001_sync.zip|65       |106    |0.6132075471698113  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0018_sync.zip|154      |270    |0.5703703703703704  |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0023_sync.zip|258      |474    |0.5443037974683544  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0096_sync.zip|243      |475    |0.511578947368421   |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0064_sync.zip|288      |570    |0.5052631578947369  |
# |train|data_object_image_2.zip  |campus     |2011_09_28_drive_0045_sync.zip|21       |43     |0.4883720930232558  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0104_sync.zip|152      |312    |0.48717948717948717 |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0039_sync.zip|192      |395    |0.4860759493670886  |
# |train|data_object_image_2.zip  |road       |2011_09_26_drive_0032_sync.zip|187      |390    |0.4794871794871795  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0059_sync.zip|178      |373    |0.4772117962466488  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0001_sync.zip|51       |108    |0.4722222222222222  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0084_sync.zip|175      |383    |0.45691906005221933 |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0048_sync.zip|10       |22     |0.45454545454545453 |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0093_sync.zip|194      |433    |0.44803695150115475 |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0035_sync.zip|57       |131    |0.4351145038167939  |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0022_sync.zip|321      |800    |0.40125             |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0061_sync.zip|275      |703    |0.3911806543385491  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0106_sync.zip|88       |227    |0.3876651982378855  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0011_sync.zip|89       |233    |0.38197424892703863 |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0091_sync.zip|128      |340    |0.3764705882352941  |
# |train|data_object_image_2.zip  |road       |2011_10_03_drive_0047_sync.zip|296      |837    |0.3536439665471924  |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0017_sync.zip|38       |114    |0.3333333333333333  |
# |train|data_object_image_2.zip  |campus     |2011_09_28_drive_0047_sync.zip|10       |31     |0.3225806451612903  |
# |train|data_object_image_2.zip  |road       |2011_09_26_drive_0028_sync.zip|131      |430    |0.30465116279069765 |
# |train|data_object_image_2.zip  |road       |2011_09_29_drive_0004_sync.zip|103      |339    |0.30383480825958703 |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0117_sync.zip|198      |660    |0.3                 |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0036_sync.zip|240      |803    |0.298879202988792   |
# |train|data_object_image_2.zip  |city       |2011_09_29_drive_0026_sync.zip|47       |158    |0.2974683544303797  |
# |train|data_object_image_2.zip  |city       |2011_09_28_drive_0002_sync.zip|107      |376    |0.2845744680851064  |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0019_sync.zip|132      |481    |0.27442827442827444 |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0051_sync.zip|112      |438    |0.2557077625570776  |
# |train|data_object_image_2.zip  |campus     |2011_09_28_drive_0038_sync.zip|26       |110    |0.23636363636363636 |
# |train|data_object_image_2.zip  |campus     |2011_09_28_drive_0037_sync.zip|21       |89     |0.23595505617977527 |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0060_sync.zip|18       |78     |0.23076923076923078 |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0046_sync.zip|28       |125    |0.224               |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0057_sync.zip|80       |361    |0.22160664819944598 |
# |train|data_object_image_2.zip  |city       |2011_09_29_drive_0071_sync.zip|208      |1059   |0.1964117091595845  |
# |train|data_object_image_2.zip  |road       |2011_09_26_drive_0070_sync.zip|72       |420    |0.17142857142857143 |
# |train|data_object_image_2.zip  |residential|2011_09_26_drive_0020_sync.zip|14       |86     |0.16279069767441862 |
# |train|data_object_image_2.zip  |person     |2011_09_28_drive_0053_sync.zip|11       |68     |0.16176470588235295 |
# |train|data_object_image_2.zip  |city       |2011_09_26_drive_0013_sync.zip|23       |144    |0.1597222222222222  |
# |train|data_object_image_2.zip  |person     |2011_09_28_drive_0146_sync.zip|11       |71     |0.15492957746478872 |
# |train|data_object_image_2.zip  |person     |2011_09_28_drive_0057_sync.zip|11       |74     |0.14864864864864866 |
# |train|data_object_image_2.zip  |person     |2011_09_28_drive_0113_sync.zip|11       |74     |0.14864864864864866 |
# |train|data_object_image_2.zip  |person     |2011_09_28_drive_0082_sync.zip|11       |75     |0.14666666666666667 |
# |train|data_object_image_2.zip  |person     |2011_09_28_drive_0106_sync.zip|11       |75     |0.14666666666666667 |
# |train|data_object_image_2.zip  |person     |2011_09_28_drive_

# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0104_sync.zip|455      |312    |1.4583333333333333  |
# |train|data_object_prev_2.zip   |residential|2011_09_26_drive_0039_sync.zip|573      |395    |1.450632911392405   |
# |train|data_object_prev_2.zip   |campus     |2011_09_28_drive_0045_sync.zip|62       |43     |1.441860465116279   |
# |train|data_object_prev_2.zip   |road       |2011_09_26_drive_0032_sync.zip|560      |390    |1.435897435897436   |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0059_sync.zip|534      |373    |1.4316353887399464  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0001_sync.zip|150      |108    |1.3888888888888888  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0084_sync.zip|525      |383    |1.370757180156658   |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0093_sync.zip|581      |433    |1.3418013856812934  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0048_sync.zip|29       |22     |1.3181818181818181  |
# |train|data_object_prev_2.zip   |residential|2011_09_26_drive_0035_sync.zip|170      |131    |1.297709923664122   |
# |train|data_object_prev_2.zip   |residential|2011_09_26_drive_0022_sync.zip|962      |800    |1.2025              |
# |train|data_object_prev_2.zip   |residential|2011_09_26_drive_0061_sync.zip|825      |703    |1.1735419630156472  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0106_sync.zip|264      |227    |1.1629955947136563  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0011_sync.zip|264      |233    |1.1330472103004292  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0091_sync.zip|384      |340    |1.1294117647058823  |
# |train|data_object_prev_2.zip   |road       |2011_10_03_drive_0047_sync.zip|888      |837    |1.060931899641577   |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0017_sync.zip|111      |114    |0.9736842105263158  |
# |train|data_object_prev_2.zip   |campus     |2011_09_28_drive_0047_sync.zip|29       |31     |0.9354838709677419  |
# |train|data_object_prev_2.zip   |road       |2011_09_26_drive_0028_sync.zip|393      |430    |0.913953488372093   |
# |train|data_object_prev_2.zip   |road       |2011_09_29_drive_0004_sync.zip|309      |339    |0.911504424778761   |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0117_sync.zip|594      |660    |0.9                 |
# |train|data_object_prev_2.zip   |residential|2011_09_26_drive_0036_sync.zip|719      |803    |0.8953922789539228  |
# |train|data_object_prev_2.zip   |city       |2011_09_29_drive_0026_sync.zip|141      |158    |0.8924050632911392  |
# |train|data_object_prev_2.zip   |city       |2011_09_28_drive_0002_sync.zip|321      |376    |0.8537234042553191  |
# |train|data_object_prev_2.zip   |residential|2011_09_26_drive_0019_sync.zip|396      |481    |0.8232848232848233  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0051_sync.zip|333      |438    |0.7602739726027398  |
# |train|data_object_prev_2.zip   |campus     |2011_09_28_drive_0038_sync.zip|78       |110    |0.7090909090909091  |
# |train|data_object_prev_2.zip   |campus     |2011_09_28_drive_0037_sync.zip|63       |89     |0.7078651685393258  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0060_sync.zip|54       |78     |0.6923076923076923  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0057_sync.zip|240      |361    |0.6648199445983379  |
# |train|data_object_prev_2.zip   |residential|2011_09_26_drive_0046_sync.zip|83       |125    |0.664               |
# |train|data_object_prev_2.zip   |city       |2011_09_29_drive_0071_sync.zip|624      |1059   |0.5892351274787535  |
# |train|data_object_prev_2.zip   |road       |2011_09_26_drive_0070_sync.zip|216      |420    |0.5142857142857142  |
# |train|data_object_prev_2.zip   |person     |2011_09_28_drive_0053_sync.zip|33       |68     |0.4852941176470588  |
# |train|data_object_prev_2.zip   |city       |2011_09_26_drive_0013_sync.zip|69       |144    |0.4791666666666667  |
# |train|data_object_prev_2.zip   |residential|2011_09_26_drive_0020_sync.zip|41       |86     |0.47674418604651164 |
# |train|data_object_prev_2.zip   |person     |2011_09_28_drive_
# |train|data_tracking_image_2.zip|city       |2011_09_26_drive_0018_sync.zip|270      |270    |1.0                 |
# |train|data_tracking_image_2.zip|residential|2011_09_26_drive_0022_sync.zip|800      |800    |1.0                 |
# |train|data_tracking_image_2.zip|road       |2011_09_26_drive_0032_sync.zip|390      |390    |1.0                 |
# |train|data_tracking_image_2.zip|residential|2011_09_26_drive_0036_sync.zip|803      |803    |1.0                 |
# |train|data_tracking_image_2.zip|city       |2011_09_26_drive_0056_sync.zip|294      |294    |1.0                 |
# |train|data_tracking_image_2.zip|city       |2011_09_26_drive_0059_sync.zip|373      |373    |1.0                 |
# |train|data_tracking_image_2.zip|city       |2011_09_26_drive_0060_sync.zip|78       |78     |1.0                 |
# |train|data_tracking_image_2.zip|city       |2011_09_26_drive_0091_sync.zip|340      |340    |1.0                 |
# |train|data_tracking_image_2.zip|city       |2011_09_28_drive_0001_sync.zip|106      |106    |1.0                 |
# |train|data_tracking_image_2.zip|city       |2011_09_28_drive_0002_sync.zip|376      |376    |1.0                 |
# |train|data_tracking_image_2.zip|campus     |2011_09_28_drive_0021_sync.zip|209      |209    |1.0                 |
# |train|data_tracking_image_2.zip|campus     |2011_09_28_drive_0043_sync.zip|145      |145    |1.0                 |
# |train|data_tracking_image_2.zip|road       |2011_09_29_drive_0004_sync.zip|339      |339    |1.0                 |
# |train|data_tracking_image_2.zip|city       |2011_09_29_drive_0071_sync.zip|1059     |1059   |1.0                 |
# |train|data_tracking_image_2.zip|road       |2011_10_03_drive_0047_sync.zip|837      |837    |1.0                 |
# +-----+-------------------------+-----------+------------------------------+---------+-------+--------------------+

# %% [markdown]
# ### How much do the Object and Tracking Benchmarks overlap?
# Above we showed that there is a complex overlap between the Tracking and Object Benchmarks.  Let's dive a little deeper.  We find that about 18% of the `train` sets overlap, and about 20% of the `test` sets overlap.

# %%
show_query("""
    SELECT 
        archive_name,
        COUNT(DISTINCT digest)
    FROM benchmark_df
    GROUP BY archive_name
""")

show_query("""
    WITH 
      obj AS (  
          SELECT
            IF(filename LIKE '%test%', 'test', 'train') AS split,
            digest,
            archive_name benchmark
          FROM benchmark_df  
          WHERE archive_name = 'data_object_image_2.zip'   ),

      track AS (  
          SELECT
            IF(filename LIKE '%test%', 'test', 'train') AS split,
            digest,
            archive_name benchmark
          FROM benchmark_df  
          WHERE archive_name = 'data_tracking_image_2.zip'   )
    
    SELECT
        obj.split obj_split,
        track.split track_split,
        COUNT(*) n,
        IF(track.split is not null, ROUND(COUNT(*) / 19103, 3), 0) frac_tracking,
        IF(obj.split is not null, ROUND(COUNT(*) / 14999, 3), 0) frac_object
    FROM obj FULL OUTER JOIN track ON obj.digest = track.digest
    GROUP BY obj_split, track_split
    ORDER BY obj_split, track_split
""")
# Out:
# +--------------------------+----------------------+
# |archive_name              |count(DISTINCT digest)|
# +--------------------------+----------------------+
# |data_tracking_image_2.zip |19103                 |
# |data_tracking_oxts.zip    |50                    |
# |data_object_prev_3.zip    |27328                 |
# |data_object_velodyne.zip  |14999                 |
# |data_tracking_velodyne.zip|19099                 |
# |data_object_image_3.zip   |14999                 |
# |data_object_image_2.zip   |14999                 |
# |data_tracking_image_3.zip |19103                 |
# |data_object_prev_2.zip    |27328                 |
# +--------------------------+----------------------+
#
# +---------+-----------+----+-------------+-----------+
# |obj_split|track_split|n   |frac_tracking|frac_object|
# +---------+-----------+----+-------------+-----------+
# |null     |test       |7542|0.395        |0.0        |
# |null     |train      |4910|0.257        |0.0        |
# |test     |null       |3965|0.0          |0.264      |
# |test     |test       |3553|0.186        |0.237      |
# |train    |null       |4383|0.0          |0.292      |
# |train    |train      |3098|0.162        |0.207      |
# +---------+-----------+----+-------------+-----------+

# %% [markdown]
# ### The Raw Sync Tracklets are a superset of the Tracking Benchmark
# Below we can see that the `train` split of the Tracking benchmark does not include all Raw Sync segments that have `tracklets.zip` files posted publicly.  We are unsure of this discrepency, but perhaps the excluded segments don't help with car/pedestrian class balance.

# %%
tracking_train_segments_df = spark.sql("""
    SELECT DISTINCT r.archive_name AS segment
    FROM benchmark_df b INNER JOIN raw_data_df r on b.digest = r.digest
    WHERE b.archive_name = 'data_tracking_image_2.zip'
""")

tracking_train_segments = set(
    r.segment.replace('.zip', '')
    for r in tracking_train_segments_df.collect())

print('Raw Sync segments excluded from Tracking Benchmark:')
pprint.pprint(set(SEGMENTS_WITH_TRACKLETS) - tracking_train_segments)
print('%s with tracklets vs %s Tracking Benchmark' % (len(SEGMENTS_WITH_TRACKLETS), tracking_train_segments_df.count()))
# Out:
# Raw Sync segments excluded from Tracking Benchmark:
# {'2011_09_26_drive_0001',
#  '2011_09_26_drive_0002',
#  '2011_09_26_drive_0005',
#  '2011_09_26_drive_0009',
#  '2011_09_26_drive_0011',
#  '2011_09_26_drive_0013',
#  '2011_09_26_drive_0014',
#  '2011_09_26_drive_0015',
#  '2011_09_26_drive_0017',
#  '2011_09_26_drive_0018',
#  '2011_09_26_drive_0019',
#  '2011_09_26_drive_0020',
#  '2011_09_26_drive_0022',
#  '2011_09_26_drive_0023',
#  '2011_09_26_drive_0027',
#  '2011_09_26_drive_0028',
#  '2011_09_26_drive_0029',
#  '2011_09_26_drive_0032',
#  '2011_09_26_drive_0035',
#  '2011_09_26_drive_0036',
#  '2011_09_26_drive_0039',
#  '2011_09_26_drive_0046',
#  '2011_09_26_drive_0048',
#  '2011_09_26_drive_0051',
#  '2011_09_26_drive_0052',
#  '2011_09_26_drive_0056',
#  '2011_09_26_drive_0057',
#  '2011_09_26_drive_0059',
#  '2011_09_26_drive_0060',
#  '2011_09_26_drive_0061',
#  '2011_09_26_drive_0064',
#  '2011_09_26_drive_0070',
#  '2011_09_26_drive_0079',
#  '2011_09_26_drive_0084',
#  '2011_09_26_drive_0086',
#  '2011_09_26_drive_0087',
#  '2011_09_26_drive_0091',
#  '2011_09_26_drive_0093'}
# 38 with tracklets vs 21 Tracking Benchmark

# %% [markdown]
# ### Preceding Image Files
# *Are there any oddities with the preceding image files? Nope*
#
# The object benchmark files with preceding images (e.g. `data_object_prev_2.zip`) likely contain some duplicates.  For example, the images at time `T` and `T-1` may have two identical preceding images.  When digging deeper, we observed that indeed there are duplicates; in fact, archives like `data_object_prev_2.zip` contain duplicate files (with differnet file names).  There are a few other observations:
#  * The `train` and `test` sets are distinct (as expected) and have a similar distributions of duplicate image files.
#  * There are no `train` preceding images that are not also represented in the `raw` data.

# %%
show_query("""
    SELECT 
        COUNT(*) distinct_files, splits, n_dupes
    FROM (
        SELECT
            digest,
            COLLECT_LIST(filename),
            COLLECT_LIST(archive_name),
            COLLECT_SET(split) AS splits,
            COUNT(*) n_dupes
        FROM (SELECT * FROM benchmark_df_with_split UNION SELECT * FROM raw_data_df_with_split)
        GROUP BY digest
        ORDER BY n_dupes DESC
    )
    GROUP BY n_dupes, splits
    ORDER BY distinct_files DESC
""")
# Out:
# +--------------+------------+-------+
# |distinct_files|splits      |n_dupes|
# +--------------+------------+-------+
# |240646        |[raw]       |1      |
# |25608         |[test]      |1      |
# |20643         |[train, raw]|2      |
# |15682         |[train, raw]|3      |
# |14023         |[test]      |2      |
# |6950          |[test]      |3      |
# |5276          |[train, raw]|4      |
# |3634          |[test]      |4      |
# |2754          |[train, raw]|5      |
# |2480          |[train, raw]|6      |
# |2366          |[test]      |5      |
# |21            |[train]     |1      |
# +--------------+------------+-------+

# %% [markdown]
# # Sensor Sample Rate Study
# One of the [KITTI papers](http://www.cvlibs.net/publications/Geiger2013IJRR.pdf) reports that the cameras and lidar are synchronized to record at 10Hz, and that the IMU (`oxts`) readings are a few milliseconds off.  Below we study this claim in detail using the timestamp data embedded in the Raw Sync datasets.
#
# This study also helps us make the Benchmarks compatible with `avsegs`.  Since the Benchmarks (**in particular the `test` split data**) do not include timestamps, but `avsegs` assumes timestamped data, we can use the results of this study to synthesize timestamps for the `test` data in `avsegs`.

# %%
def to_topic_time_df(spark, archive_paths):
    
    def to_rows(fw):
        topic = os.path.basename(os.path.dirname(fw.name))
        
        ts_lines = fw.data.decode("utf-8").split('\n')
        def to_nanostamp(line):
            import datetime
            import time
            sec_str, ns_str = line.split('.')
            t_sec = time.mktime(
                datetime.datetime.strptime(sec_str, '%Y-%m-%d %H:%M:%S').timetuple())
            t_nsec = int(ns_str)
            return int(t_sec * 1e9) + t_nsec
            
        ts = [to_nanostamp(line) for line in ts_lines if line]
        
        segment = os.path.basename(fw.archive.archive_path).replace('.zip', '')
        for frame_id, t in enumerate(ts):
            # Deduce the path to the data file for this frame
            if topic == 'oxts':
                extension = '.txt'
            elif topic == 'velodyne_points':
                extension = '.bin'
            else:
                extension = '.png'
            N_DIGITS = 10
            frame_fname = str(frame_id)
            frame_fname = ('0' * (10 - len(frame_fname))) + frame_fname
                # Left-pad with 0s; 17 -> 0000000017
            frame_fname = fw.name.replace('timestamps.txt', 'data/' + frame_fname + extension)
            
            from pyspark.sql import Row
            yield Row(
                segment=segment,
                topic=topic,
                frame=frame_id,
                nanostamp=t,
                filename=frame_fname)

    def to_fws(path):
        fws = util.ArchiveFileFlyweight.fws_from(path)
        return [fw for fw in fws if fw.name.endswith('timestamps.txt')]
    
    path_rdd = spark.sparkContext.parallelize(archive_paths)
    fw_rdd = path_rdd.flatMap(to_fws)
    df = spark.createDataFrame(fw_rdd.flatMap(to_rows))
    return df

rpaths = [
    path
    for path in glob.glob(os.path.join(KITTI_DATA_BASE_DIR, '*'))
    if is_raw_data_zip(path)
]

topic_time_df = to_topic_time_df(spark, rpaths)

# %%
# Quick sanity check
topic_time_df = topic_time_df.persist()
topic_time_df.filter('topic like "%image%"').show(truncate=False)
topic_time_df.count()
topic_time_df.createOrReplaceTempView('topic_time_df')
# Out:
# +------------------------------------------------------------------+-----+-------------------+--------------------------+--------+
# |filename                                                          |frame|nanostamp          |segment                   |topic   |
# +------------------------------------------------------------------+-----+-------------------+--------------------------+--------+
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000000.png|0    |1317046695077571328|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000001.png|1    |1317046695179708672|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000002.png|2    |1317046695283594496|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000003.png|3    |1317046695389738496|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000004.png|4    |1317046695489331200|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000005.png|5    |1317046695592591616|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000006.png|6    |1317046695695847680|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000007.png|7    |1317046695799277056|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000008.png|8    |1317046695902483968|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000009.png|9    |1317046696005735424|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000010.png|10   |1317046696109118208|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000011.png|11   |1317046696212424192|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000012.png|12   |1317046696315686400|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000013.png|13   |1317046696419180288|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000014.png|14   |1317046696522308352|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000015.png|15   |1317046696625835264|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000016.png|16   |1317046696729785856|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000017.png|17   |1317046696832334848|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000018.png|18   |1317046696935606016|2011_09_26_drive_0051_sync|image_00|
# |2011_09_26/2011_09_26_drive_0051_sync/image_00/data/0000000019.png|19   |1317046697039304960|2011_09_26_drive_0051_sync|image_00|
# +------------------------------------------------------------------+-----+-------------------+--------------------------+--------+
# only showing top 20 rows

# %%
# Generate a nice report
segments = [r.segment for r in topic_time_df.select('segment').distinct().collect()]
for segment in segments:
    df = topic_time_df.filter(topic_time_df.segment == segment).toPandas()
    
    from datetime import datetime
    dt = datetime.utcfromtimestamp(df['nanostamp'].min() * 1e-9)
    start = dt.strftime('%Y-%m-%d %H:%M:%S')
    duration = 1e-9 * (df['nanostamp'].max() - df['nanostamp'].min())
    
    n_images = len(df[df['topic'] == 'image_02'])
    n_lidars = len(df[df['topic'] == 'velodyne_points'])
    n_frames = df['frame'].max() + 1
    
    # Print a report
    print('---')
    print('---')

    print('Segment %s' % segment)
    print('Start %s \tDuration %s sec' % (start, duration))
    print('Num Images %s (Lidars %s)' % (n_images, n_lidars))
    import pandas as pd
    from collections import OrderedDict
    rows = []
    for name in sorted(df['topic'].unique()):
        def get_series(name):
            srows = df[df['topic'] == name]
            fids = pd.DataFrame({'frame': range(n_frames)}, columns=['frame'])
            srows = srows.set_index('frame')
            fids = fids.set_index('frame')
            joined = fids.join(srows, on='frame', how='left').fillna(0)
            return 1e-9 * joined['nanostamp'].to_numpy()

        series = get_series(name)
        freqs = series[1:] - series[:-1]

        image_series = get_series('image_02')
        all_diff_ms = 1e3 * np.abs(image_series - series)
        diff_image_ms = np.mean(all_diff_ms)
        diff_image_ms_stdev = np.std(all_diff_ms)
        
        
        rows.append(OrderedDict((
          ('Series',             name),
          ('Freq Hz',            1. / np.mean(freqs)),
          ('Diff img (msec)',    diff_image_ms),
          ('std (msec)',         diff_image_ms_stdev),
          ('Duration',           (series[-1] - series[0])),
          ('Support',            len(series)),
        )))
    print(pd.DataFrame(rows))

    print()
    print()
# Out:
# ---
# ---
# Segment 2011_09_26_drive_0104_sync
# Start 2011-09-26 15:30:02 	Duration 32.19432861 sec
# Num Images 312 (Lidars 312)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.665068         6.635582    0.968101  32.177737      312
# 1         image_01  9.665040         6.418097    0.697128  32.177829      312
# 2         image_02  9.665039         0.000000    0.000000  32.177831      312
# 3         image_03  9.665047         0.544529    0.071898  32.177805      312
# 4             oxts  9.666975         7.907448    4.793579  32.171387      312
# 5  velodyne_points  9.665116        10.512416    0.053337  32.177574      312
#
#
# ---
# ---
# Segment 2011_09_28_drive_0102_sync
# Start 2011-09-28 13:42:00 	Duration 4.65559889 sec
# Num Images 46 (Lidars 46)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.685711         6.131856    0.032090  4.646019       46
# 1         image_01  9.685618         6.128866    0.031075  4.646064       46
# 2         image_02  9.685662         0.000000    0.000000  4.646043       46
# 3         image_03  9.685917         0.552504    0.060342  4.645920       46
# 4             oxts  9.676340         5.978066    2.879269  4.650519       46
# 5  velodyne_points  9.685858         1.600608    0.032782  4.645949       46
#
#
# ---
# ---
# Segment 2011_09_26_drive_0056_sync
# Start 2011-09-26 14:27:16 	Duration 30.303387405000002 sec
# Num Images 294 (Lidars 294)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.675286         6.624929    0.822891  30.283343      294
# 1         image_01  9.675287         6.302158    0.522646  30.283339      294
# 2         image_02  9.675288         0.000000    0.000000  30.283336      294
# 3         image_03  9.675289         0.545378    0.079465  30.283333      294
# 4             oxts  9.672729         6.530611    3.070165  30.291349      294
# 5  velodyne_points  9.675287        10.496474    0.092694  30.283338      294
#
#
# ---
# ---
# Segment 2011_09_26_drive_0095_sync
# Start 2011-09-26 15:20:11 	Duration 27.645379042000002 sec
# Num Images 268 (Lidars 268)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.665028         6.382499    0.571534  27.625372      268
# 1         image_01  9.665016         6.325166    0.483180  27.625407      268
# 2         image_02  9.665015         0.000000    0.000000  27.625410      268
# 3         image_03  9.665007         0.546200    0.065530  27.625432      268
# 4             oxts  9.662994         6.398793    3.450384  27.631187      268
# 5  velodyne_points  9.665006        10.511354    0.057852  27.625435      268
#
#
# ---
# ---
# Segment 2011_09_28_drive_0037_sync
# Start 2011-09-28 12:47:09 	Duration 9.131438951 sec
# Num Images 89 (Lidars 89)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.649292         6.140444    0.016353  9.119840       89
# 1         image_01  9.649317         6.135300    0.013437  9.119816       89
# 2         image_02  9.649314         0.000000    0.000000  9.119819       89
# 3         image_03  9.649315         0.555794    0.059490  9.119818       89
# 4             oxts  9.648195         6.283998    2.899025  9.120877       89
# 5  velodyne_points  9.649364         1.691714    0.029770  9.119772       89
#
#
# ---
# ---
# Segment 2011_09_26_drive_0064_sync
# Start 2011-09-26 14:38:23 	Duration 58.865393697 sec
# Num Images 570 (Lidars 570)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.668892         6.536892    0.794485  58.848523      570
# 1         image_01  9.668857         6.396500    0.656120  58.848734      570
# 2         image_02  9.668954         0.000000    0.000000  58.848144      570
# 3         image_03  9.668933         0.541377    0.065483  58.848272      570
# 4             oxts  9.669516         6.597285    3.088882  58.844726      570
# 5  velodyne_points  9.668951        10.471518    0.157921  58.848163      570
#
#
# ---
# ---
# Segment 2011_09_26_drive_0028_sync
# Start 2011-09-26 13:22:48 	Duration 44.445416223 sec
# Num Images 430 (Lidars 430)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.655935         6.474308    0.678468  44.428635      430
# 1         image_01  9.655925         6.392096    0.660889  44.428678      430
# 2         image_02  9.655940         0.000000    0.000000  44.428613      430
# 3         image_03  9.655937         0.555579    0.096519  44.428622      430
# 4             oxts  9.655230         6.653511    3.385045  44.431878      430
# 5  velodyne_points  9.655946        10.507161    0.138202  44.428582      430
#
#
# ---
# ---
# Segment 2011_10_03_drive_0047_sync
# Start 2011-10-03 14:57:27 	Duration 86.639101952 sec
# Num Images 837 (Lidars 837)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.649974         6.178334    0.166444  86.632359      837
# 1         image_01  9.649967         6.169207    0.138780  86.632420      837
# 2         image_02  9.649976         0.000000    0.000000  86.632336      837
# 3         image_03  9.649984         0.543347    0.068289  86.632265      837
# 4             oxts  9.650203         6.164384    2.888155  86.630304      837
# 5  velodyne_points  9.649968         1.132453    0.485683  86.632412      837
#
#
# ---
# ---
# Segment 2011_09_28_drive_0080_sync
# Start 2011-09-28 13:30:40 	Duration 4.041851136 sec
# Num Images 40 (Lidars 40)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.665204         6.135023    0.021710  4.035093       40
# 1         image_01  9.665183         6.131756    0.021120  4.035102       40
# 2         image_02  9.665176         0.000000    0.000000  4.035105       40
# 3         image_03  9.664890         0.548846    0.061111  4.035224       40
# 4             oxts  9.676570         6.091213    2.835354  4.030354       40
# 5  velodyne_points  9.664988         1.579624    0.036924  4.035184       40
#
#
# ---
# ---
# Segment 2011_09_28_drive_0167_sync
# Start 2011-09-28 14:06:45 	Duration 5.475899197 sec
# Num Images 54 (Lidars 54)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.693621         6.141866    0.010062  5.467513       54
# 1         image_01  9.693621         6.137587    0.006159  5.467513       54
# 2         image_02  9.693645         0.000000    0.000000  5.467499       54
# 3         image_03  9.693620         0.543974    0.061308  5.467514       54
# 4             oxts  9.688789         6.163721    2.881220  5.470240       54
# 5  velodyne_points  9.693549         1.605542    0.038408  5.467554       54
#
#
# ---
# ---
# Segment 2011_09_28_drive_0204_sync
# Start 2011-09-28 14:13:50 	Duration 5.167549341 sec
# Num Images 51 (Lidars 51)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.693961         6.131827    0.033587  5.157850       51
# 1         image_01  9.693962         6.128886    0.035378  5.157850       51
# 2         image_02  9.693967         0.000000    0.000000  5.157847       51
# 3         image_03  9.693960         0.552243    0.059825  5.157851       51
# 4             oxts  9.688937         6.062484    2.897543  5.160525       51
# 5  velodyne_points  9.694037         1.595506    0.039773  5.157810       51
#
#
# ---
# ---
# Segment 2011_09_28_drive_0075_sync
# Start 2011-09-28 13:29:36 	Duration 7.148077056000001 sec
# Num Images 70 (Lidars 70)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.662058         6.139278    0.018162  7.141335       70
# 1         image_01  9.662056         6.133672    0.017074  7.141337       70
# 2         image_02  9.662049         0.000000    0.000000  7.141342       70
# 3         image_03  9.661900         0.543383    0.059081  7.141453       70
# 4             oxts  9.663069         6.216884    2.910284  7.140589       70
# 5  velodyne_points  9.662044         1.584353    0.033243  7.141346       70
#
#
# ---
# ---
# Segment 2011_09_26_drive_0113_sync
# Start 2011-09-26 15:37:41 	Duration 8.910861353000001 sec
# Num Images 87 (Lidars 87)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.671573         7.047837    1.296396  8.892039       87
# 1         image_01  9.671261         6.527136    0.848022  8.892325       87
# 2         image_02  9.671261         0.000000    0.000000  8.892325       87
# 3         image_03  9.671392         0.540426    0.064002  8.892205       87
# 4             oxts  9.673636         7.287078    3.295773  8.890142       87
# 5  velodyne_points  9.671354        10.503857    0.067963  8.892240       87
#
#
# ---
# ---
# Segment 2011_09_28_drive_0089_sync
# Start 2011-09-28 13:32:55 	Duration 3.834309376 sec
# Num Images 38 (Lidars 38)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.666771         6.241717    0.424130  3.827545       38
# 1         image_01  9.666711         6.228202    0.412026  3.827569       38
# 2         image_02  9.666646         0.000000    0.000000  3.827594       38
# 3         image_03  9.666361         0.559901    0.101382  3.827707       38
# 4             oxts  9.685744         6.298555    3.018800  3.820047       38
# 5  velodyne_points  9.666576         1.567113    0.084469  3.827622       38
# ---
# ---
# Segment 2011_09_28_drive_0208_sync
# Start 2011-09-28 14:14:41 	Duration 5.474233005 sec
# Num Images 54 (Lidars 54)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.695847         6.128567    0.037494  5.466258       54
# 1         image_01  9.695844         6.129826    0.028417  5.466259       54
# 2         image_02  9.695843         0.000000    0.000000  5.466260       54
# 3         image_03  9.695846         0.561608    0.060171  5.466259       54
# 4             oxts  9.688291         6.265976    2.899946  5.470521       54
# 5  velodyne_points  9.695853         1.598866    0.040474  5.466254       54
#
#
# ---
# ---
# Segment 2011_09_26_drive_0014_sync
# Start 2011-09-26 13:11:15 	Duration 32.429831132000004 sec
# Num Images 314 (Lidars 314)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.656624         6.442693    0.648236  32.412983      314
# 1         image_01  9.657144         6.362273    0.553342  32.411237      314
# 2         image_02  9.657151         0.000000    0.000000  32.411215      314
# 3         image_03  9.657151         0.537761    0.068565  32.411216      314
# 4             oxts  9.657097         6.463313    3.213428  32.411397      314
# 5  velodyne_points  9.657149        10.487970    0.211437  32.411223      314
#
#
# ---
# ---
# Segment 2011_09_28_drive_0199_sync
# Start 2011-09-28 14:12:59 	Duration 3.5138017280000002 sec
# Num Images 35 (Lidars 35)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.694754         6.140314    0.007628  3.507051       35
# 1         image_01  9.694821         6.136819    0.004086  3.507027       35
# 2         image_02  9.694804         0.000000    0.000000  3.507033       35
# 3         image_03  9.694812         0.558111    0.061146  3.507030       35
# 4             oxts  9.713392         6.092746    2.895835  3.500322       35
# 5  velodyne_points  9.694752         1.606641    0.042235  3.507052       35
#
#
# ---
# ---
# Segment 2011_09_30_drive_0016_sync
# Start 2011-09-30 11:50:40 	Duration 28.948411904 sec
# Num Images 279 (Lidars 279)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.605529         6.178434    0.344941  28.941665      279
# 1         image_01  9.605529         6.165267    0.256787  28.941664      279
# 2         image_02  9.605532         0.000000    0.000000  28.941655      279
# 3         image_03  9.605529         0.554186    0.112317  28.941664      279
# 4             oxts  9.606330         6.164539    2.869064  28.939251      279
# 5  velodyne_points  9.605622         1.633674    0.144864  28.941386      279
#
#
# ---
# ---
# Segment 2011_09_26_drive_0020_sync
# Start 2011-09-26 13:15:07 	Duration 8.82377458 sec
# Num Images 86 (Lidars 86)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.654688         6.487722    0.721349  8.804013       86
# 1         image_01  9.651606         6.382288    0.576280  8.806825       86
# 2         image_02  9.651614         0.000000    0.000000  8.806817       86
# 3         image_03  9.651612         0.539708    0.063270  8.806819       86
# 4             oxts  9.658616         6.274151    2.953247  8.800432       86
# 5  velodyne_points  9.651624        10.515917    0.055467  8.806808       86
#
#
# ---
# ---
# Segment 2011_09_28_drive_0216_sync
# Start 2011-09-28 14:16:14 	Duration 5.992262258 sec
# Num Images 59 (Lidars 59)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.695985         6.193751    0.186612  5.981857       59
# 1         image_01  9.695992         6.183362    0.193577  5.981853       59
# 2         image_02  9.696066         0.000000    0.000000  5.981807       59
# 3         image_03  9.696064         0.544863    0.062440  5.981809       59
# 4             oxts  9.681953         6.083497    2.922063  5.990527       59
# 5  velodyne_points  9.696039         1.641892    0.204155  5.981824       59
#
#
# ---
# ---
# Segment 2011_09_30_drive_0027_sync
# Start 2011-09-30 12:40:25 	Duration 114.856292096 sec
# Num Images 1106 (Lidars 1106)
#             Series   Freq Hz  Diff img (msec)  std (msec)    Duration  Support
# 0         image_00  9.621280         6.181858    0.264671  114.849581     1106
# 1         image_01  9.621280         6.176960    0.259891  114.849582     1106
# 2         image_02  9.621280         0.000000    0.000000  114.849581     1106
# 3         image_03  9.621283         0.546810    0.063025  114.849542     1106
# 4             oxts  9.621425         6.216471    2.907320  114.847852     1106
# 5  velodyne_points  9.621289         1.507892    0.197202  114.849476     1106
#
#
# ---
# ---
# Segment 2011_09_28_drive_0220_sync
# Start 2011-09-28 14:17:41 	Duration 7.94977536 sec
# Num Images 78 (Lidars 78)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.694048         6.226812    0.399671  7.943018       78
# 1         image_01  9.694080         6.222465    0.393909  7.942992       78
# 2         image_02  9.694010         0.000000    0.000000  7.943049       78
# 3         image_03  9.694009         0.563114    0.059855  7.943050       78
# 4             oxts  9.696818         6.177899    2.901026  7.940749       78
# 5  velodyne_points  9.694026         1.585276    0.041965  7.943036       78
#
#
# ---
# ---
# Segment 2011_09_28_drive_0174_sync
# Start 2011-09-28 14:08:26 	Duration 5.473760256 sec
# Num Images 54 (Lidars 54)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.694551         6.137490    0.017055  5.466989       54
# 1         image_01  9.694511         6.132735    0.017094  5.467011       54
# 2         image_02  9.694513         0.000000    0.000000  5.467010       54
# 3         image_03  9.694510         0.558858    0.059087  5.467012       54
# 4             oxts  9.688198         6.128616    2.890273  5.470574       54
# 5  velodyne_points  9.694559         1.606787    0.034275  5.466984       54
#
#
# ---
# ---
# Segment 2011_09_28_drive_0161_sync
# Start 2011-09-28 14:05:22 	Duration 3.7218495590000003 sec
# Num Images 37 (Lidars 37)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.696825         6.142088    0.023616  3.712555       37
# 1         image_01  9.696827         6.131862    0.020433  3.712555       37
# 2         image_02  9.696854         0.000000    0.000000  3.712544       37
# 3         image_03  9.696832         0.548769    0.061611  3.712553       37
# 4             oxts  9.702588         6.147372    2.953083  3.710350       37
# 5  velodyne_points  9.696920         1.603964    0.041297  3.712519       37
#
#
# ---
# ---
# Segment 2011_09_28_drive_0082_sync
# Start 2011-09-28 13:31:14 	Duration 7.664303616000001 sec
# Num Images 75 (Lidars 75)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.663679         6.232713    0.309358  7.657539       75
# 1         image_01  9.663885         6.216380    0.278322  7.657376       75
# 2         image_02  9.664191         0.000000    0.000000  7.657133       75
# 3         image_03  9.664177         0.545721    0.062121  7.657145       75
# 4             oxts  9.672159         6.169198    2.891886  7.650826       75
# 5  velodyne_points  9.664219         1.591215    0.042390  7.657111       75
#
#
# ---
# ---
# Segment 2011_09_30_drive_0034_sync
# Start 2011-09-30 13:16:05 	Duration 126.88600576 sec
# Num Images 1224 (Lidars 1224)
#             Series   Freq Hz  Diff img (msec)  std (msec)    Duration  Support
# 0         image_00  9.639086         6.140059    0.034641  126.879253     1224
# 1         image_01  9.639086         6.136765    0.029128  126.879255     1224
# 2         image_02  9.639085         0.000000    0.000000  126.879257     1224
# 3         image_03  9.639076         0.551396    0.062738  126.879380     1224
# 4             oxts  9.639226         6.081491    2.884005  126.877402     1224
# 5  velodyne_points  9.639087         1.624093    0.135715  126.879242     1224
#
#
# ---
# ---
# Segment 2011_09_28_drive_0149_sync
# Start 2011-09-28 14:02:39 	Duration 4.651633223 sec
# Num Images 46 (Lidars 46)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.693490         6.135832    0.018961  4.642291       46
# 1         image_01  9.693489         6.133038    0.017738  4.642291       46
# 2         image_02  9.693481         0.000000    0.000000  4.642295       46
# 3         image_03  9.693230         0.541894    0.059563  4.642416       46
# 4             oxts  9.697880         6.179784    2.954216  4.640189       46
# 5  velodyne_points  9.693416         1.605345    0.037763  4.642326       46
# ---
# ---
# Segment 2011_09_28_drive_0034_sync
# Start 2011-09-28 12:46:15 	Duration 4.980687883 sec
# Num Images 49 (Lidars 49)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.651233         6.170000    0.147200  4.973458       49
# 1         image_01  9.651271         6.164955    0.143738  4.973438       49
# 2         image_02  9.651269         0.000000    0.000000  4.973439       49
# 3         image_03  9.651028         0.548353    0.084506  4.973563       49
# 4             oxts  9.657027         6.197603    2.876082  4.970474       49
# 5  velodyne_points  9.651146         1.657316    0.477587  4.973503       49
#
#
# ---
# ---
# Segment 2011_09_26_drive_0051_sync
# Start 2011-09-26 14:18:15 	Duration 45.217125954000004 sec
# Num Images 438 (Lidars 438)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.668678         6.511785    0.784826  45.197495      438
# 1         image_01  9.668667         6.516293    0.822180  45.197546      438
# 2         image_02  9.668671         0.000000    0.000000  45.197524      438
# 3         image_03  9.668685         0.553825    0.099088  45.197460      438
# 4             oxts  9.667770         6.718132    3.143203  45.201740      438
# 5  velodyne_points  9.668687        10.496548    0.173439  45.197448      438
#
#
# ---
# ---
# Segment 2011_09_28_drive_0134_sync
# Start 2011-09-28 13:49:44 	Duration 5.580059176000001 sec
# Num Images 55 (Lidars 55)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.690002         6.137419    0.008447  5.572754       55
# 1         image_01  9.689965         6.134579    0.006916  5.572776       55
# 2         image_02  9.689967         0.000000    0.000000  5.572775       55
# 3         image_03  9.689964         0.550903    0.058916  5.572776       55
# 4             oxts  9.693987         6.050175    2.839823  5.570463       55
# 5  velodyne_points  9.689952         1.604345    0.035355  5.572783       55
#
#
# ---
# ---
# Segment 2011_09_26_drive_0096_sync
# Start 2011-09-26 15:20:55 	Duration 49.039452706000006 sec
# Num Images 475 (Lidars 475)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.668979         6.471574    0.721000  49.022758      475
# 1         image_01  9.668972         6.513613    0.765239  49.022792      475
# 2         image_02  9.668974         0.000000    0.000000  49.022784      475
# 3         image_03  9.668981         0.546838    0.064082  49.022746      475
# 4             oxts  9.669108         6.394351    3.319167  49.022100      475
# 5  velodyne_points  9.668974        10.507470    0.059617  49.022780      475
#
#
# ---
# ---
# Segment 2011_09_28_drive_0119_sync
# Start 2011-09-28 13:46:44 	Duration 7.852604094 sec
# Num Images 77 (Lidars 77)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.689932         6.134306    0.030072  7.843193       77
# 1         image_01  9.689964         6.129773    0.027043  7.843167       77
# 2         image_02  9.689960         0.000000    0.000000  7.843169       77
# 3         image_03  9.689962         0.544697    0.060006  7.843168       77
# 4             oxts  9.680581         6.000466    2.899759  7.850768       77
# 5  velodyne_points  9.690033         1.604018    0.037172  7.843111       77
#
#
# ---
# ---
# Segment 2011_09_28_drive_0121_sync
# Start 2011-09-28 13:47:08 	Duration 4.651166208 sec
# Num Images 46 (Lidars 46)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.689048         6.136599    0.019684  4.644419       46
# 1         image_01  9.689048         6.133385    0.018213  4.644419       46
# 2         image_02  9.689046         0.000000    0.000000  4.644420       46
# 3         image_03  9.689054         0.563228    0.058317  4.644416       46
# 4             oxts  9.697527         6.065649    2.878074  4.640358       46
# 5  velodyne_points  9.689103         1.597337    0.035624  4.644393       46
#
#
# ---
# ---
# Segment 2011_09_26_drive_0036_sync
# Start 2011-09-26 14:02:22 	Duration 82.808615215 sec
# Num Images 803 (Lidars 803)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.686936         6.482915    0.746860  82.791920      803
# 1         image_01  9.687202         6.391646    0.615347  82.789647      803
# 2         image_02  9.686941         0.000000    0.000000  82.791873      803
# 3         image_03  9.686921         0.539385    0.067006  82.792048      803
# 4             oxts  9.687911         6.637860    3.566971  82.783581      803
# 5  velodyne_points  9.686934        10.490138    0.094488  82.791932      803
#
#
# ---
# ---
# Segment 2011_09_28_drive_0192_sync
# Start 2011-09-28 14:11:46 	Duration 8.673228389 sec
# Num Images 85 (Lidars 85)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.695661         6.149068    0.034100  8.663670       85
# 1         image_01  9.695639         6.164497    0.190016  8.663689       85
# 2         image_02  9.695709         0.000000    0.000000  8.663626       85
# 3         image_03  9.695672         0.538632    0.060155  8.663660       85
# 4             oxts  9.687513         6.089623    2.905778  8.670956       85
# 5  velodyne_points  9.695673         1.609410    0.037948  8.663658       85
#
#
# ---
# ---
# Segment 2011_09_26_drive_0057_sync
# Start 2011-09-26 14:30:15 	Duration 37.297596028 sec
# Num Images 361 (Lidars 361)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.656412         6.588326    0.842173  37.280926      361
# 1         image_01  9.656409         6.370749    0.622217  37.280939      361
# 2         image_02  9.656433         0.000000    0.000000  37.280849      361
# 3         image_03  9.656432         0.544707    0.062870  37.280849      361
# 4             oxts  9.656216         6.647358    3.046349  37.281684      361
# 5  velodyne_points  9.656430        10.508222    0.055632  37.280857      361
#
#
# ---
# ---
# Segment 2011_09_28_drive_0095_sync
# Start 2011-09-28 13:34:24 	Duration 4.144568519 sec
# Num Images 41 (Lidars 41)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.669116         6.209705    0.181536  4.136883       41
# 1         image_01  9.668978         6.173326    0.082290  4.136942       41
# 2         image_02  9.669144         0.000000    0.000000  4.136871       41
# 3         image_03  9.669466         0.556649    0.063779  4.136733       41
# 4             oxts  9.660766         6.332642    2.882922  4.140459       41
# 5  velodyne_points  9.669235         1.588560    0.038927  4.136832       41
#
#
# ---
# ---
# Segment 2011_10_03_drive_0042_sync
# Start 2011-10-03 14:34:18 	Duration 121.192305754 sec
# Num Images 1170 (Lidars 1170)
#             Series   Freq Hz  Diff img (msec)  std (msec)    Duration  Support
# 0         image_00  9.646625         6.163073    0.179111  121.182282     1170
# 1         image_01  9.646625         6.158062    0.155685  121.182281     1170
# 2         image_02  9.646625         0.000000    0.000000  121.182274     1170
# 3         image_03  9.646617         0.545306    0.111167  121.182379     1170
# 4             oxts  9.646306         6.147585    2.890447  121.186282     1170
# 5  velodyne_points  9.646602         1.737524    0.167208  121.182570     1170
#
#
# ---
# ---
# Segment 2011_09_28_drive_0053_sync
# Start 2011-09-28 13:19:12 	Duration 6.94667729 sec
# Num Images 68 (Lidars 68)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.658132         6.141933    0.008600  6.937159       68
# 1         image_01  9.658163         6.138437    0.007339  6.937137       68
# 2         image_02  9.658091         0.000000    0.000000  6.937188       68
# 3         image_03  9.658089         0.565743    0.057974  6.937190       68
# 4             oxts  9.653253         6.127648    2.885452  6.940665       68
# 5  velodyne_points  9.658041         1.568489    0.034230  6.937225       68
#
#
# ---
# ---
# Segment 2011_09_28_drive_0143_sync
# Start 2011-09-28 14:01:32 	Duration 3.207138791 sec
# Num Images 32 (Lidars 32)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.692571         6.135464    0.037233  3.198326       32
# 1         image_01  9.692470         6.135531    0.034189  3.198359       32
# 2         image_02  9.692444         0.000000    0.000000  3.198368       32
# 3         image_03  9.692437         0.553280    0.060864  3.198370       32
# 4             oxts  9.686644         6.394960    2.879081  3.200283       32
# 5  velodyne_points  9.693025         1.624331    0.065209  3.198176       32
#
#
# ---
# ---
# Segment 2011_09_28_drive_0001_sync
# Start 2011-09-28 12:26:17 	Duration 10.891517184000001 sec
# Num Images 106 (Lidars 106)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.646508         6.119141    0.047608  10.884767      106
# 1         image_01  9.646509         6.125221    0.033281  10.884767      106
# 2         image_02  9.646507         0.000000    0.000000  10.884769      106
# 3         image_03  9.646507         0.557018    0.060517  10.884769      106
# 4             oxts  9.649844         6.120803    2.871537  10.881005      106
# 5  velodyne_points  9.645684         0.960609    0.367690  10.885698      106
#
#
# ---
# ---
# Segment 2011_09_28_drive_0108_sync
# Start 2011-09-28 13:43:51 	Duration 4.8583493120000005 sec
# Num Images 48 (Lidars 48)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.687310         6.243144    0.279029  4.851708       48
# 1         image_01  9.687357         6.206885    0.238749  4.851684       48
# 2         image_02  9.689849         0.000000    0.000000  4.850437       48
# 3         image_03  9.690075         0.548025    0.061895  4.850323       48
# 4             oxts  9.689948         6.015350    2.874509  4.850387       48
# 5  velodyne_points  9.689852         1.604711    0.060346  4.850435       48
# ---
# ---
# Segment 2011_09_28_drive_0209_sync
# Start 2011-09-28 14:14:49 	Duration 8.773894912000001 sec
# Num Images 86 (Lidars 86)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.695150         6.138469    0.016203  8.767270       86
# 1         image_01  9.695151         6.134607    0.014029  8.767270       86
# 2         image_02  9.695152         0.000000    0.000000  8.767268       86
# 3         image_03  9.695151         0.545701    0.059385  8.767269       86
# 4             oxts  9.702322         6.186704    2.875036  8.760790       86
# 5  velodyne_points  9.695145         1.609018    0.038476  8.767275       86
#
#
# ---
# ---
# Segment 2011_09_28_drive_0179_sync
# Start 2011-09-28 14:09:16 	Duration 4.339706280000001 sec
# Num Images 43 (Lidars 43)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.693684         6.138386    0.021530  4.332718       43
# 1         image_01  9.693604         6.133418    0.018736  4.332754       43
# 2         image_02  9.693611         0.000000    0.000000  4.332751       43
# 3         image_03  9.693618         0.561032    0.058765  4.332748       43
# 4             oxts  9.698328         6.125117    2.835070  4.330643       43
# 5  velodyne_points  9.693572         1.596706    0.036930  4.332768       43
#
#
# ---
# ---
# Segment 2011_09_28_drive_0035_sync
# Start 2011-09-28 12:46:43 	Duration 3.5314926590000004 sec
# Num Images 35 (Lidars 35)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.651723         6.133189    0.030634  3.522687       35
# 1         image_01  9.651787         6.128522    0.028974  3.522664       35
# 2         image_02  9.651794         0.000000    0.000000  3.522661       35
# 3         image_03  9.651787         0.553165    0.059626  3.522664       35
# 4             oxts  9.658125         6.312786    2.897324  3.520352       35
# 5  velodyne_points  9.651550         1.605497    0.046854  3.522750       35
#
#
# ---
# ---
# Segment 2011_09_29_drive_0026_sync
# Start 2011-09-29 13:04:07 	Duration 16.322596608 sec
# Num Images 158 (Lidars 158)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.622597         6.241011    0.316240  16.315762      158
# 1         image_01  9.622570         6.248328    0.276411  16.315808      158
# 2         image_02  9.622584         0.000000    0.000000  16.315784      158
# 3         image_03  9.622509         0.541735    0.064411  16.315911      158
# 4             oxts  9.627054         5.910700    2.981505  16.308209      158
# 5  velodyne_points  9.622535         1.818008    0.043237  16.315867      158
#
#
# ---
# ---
# Segment 2011_09_28_drive_0016_sync
# Start 2011-09-28 12:36:08 	Duration 19.186137889 sec
# Num Images 186 (Lidars 186)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.646538         6.137521    0.019818  19.177865      186
# 1         image_01  9.646538         6.134079    0.018349  19.177866      186
# 2         image_02  9.646536         0.000000    0.000000  19.177868      186
# 3         image_03  9.646536         0.553168    0.059928  19.177868      186
# 4             oxts  9.644538         6.313674    2.880436  19.181841      186
# 5  velodyne_points  9.646562         1.514491    0.035589  19.177816      186
#
#
# ---
# ---
# Segment 2011_09_26_drive_0018_sync
# Start 2011-09-26 13:13:32 	Duration 27.891070377000002 sec
# Num Images 270 (Lidars 270)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.650917         6.452718    0.635202  27.872998      270
# 1         image_01  9.650411         6.396419    0.636873  27.874461      270
# 2         image_02  9.650944         0.000000    0.000000  27.872922      270
# 3         image_03  9.650901         0.542895    0.064306  27.873045      270
# 4             oxts  9.651617         6.622271    2.951387  27.870977      270
# 5  velodyne_points  9.650908        10.510656    0.047217  27.873024      270
#
#
# ---
# ---
# Segment 2011_09_26_drive_0084_sync
# Start 2011-09-26 15:02:53 	Duration 39.599387105000005 sec
# Num Images 383 (Lidars 383)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.651005         6.487052    0.723356  39.581369      383
# 1         image_01  9.650740         6.375624    0.650414  39.582458      383
# 2         image_02  9.650962         0.000000    0.000000  39.581545      383
# 3         image_03  9.650962         0.547047    0.065247  39.581545      383
# 4             oxts  9.650956         6.259784    2.955828  39.581570      383
# 5  velodyne_points  9.650944        10.512806    0.082541  39.581620      383
#
#
# ---
# ---
# Segment 2011_09_28_drive_0125_sync
# Start 2011-09-28 13:47:57 	Duration 5.994746189000001 sec
# Num Images 59 (Lidars 59)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.690759         6.187976    0.090709  5.985083       59
# 1         image_01  9.690738         6.178626    0.073893  5.985096       59
# 2         image_02  9.690796         0.000000    0.000000  5.985060       59
# 3         image_03  9.690969         0.536422    0.060554  5.984954       59
# 4             oxts  9.681883         6.256782    2.911148  5.990570       59
# 5  velodyne_points  9.691325         1.770601    0.538706  5.984734       59
#
#
# ---
# ---
# Segment 2011_09_28_drive_0100_sync
# Start 2011-09-28 13:41:26 	Duration 7.8544209920000005 sec
# Num Images 77 (Lidars 77)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.684274         6.135996    0.024136  7.847775       77
# 1         image_01  9.684242         6.133210    0.024769  7.847800       77
# 2         image_02  9.684257         0.000000    0.000000  7.847789       77
# 3         image_03  9.684402         0.562488    0.058895  7.847671       77
# 4             oxts  9.692825         6.040431    2.895368  7.840851       77
# 5  velodyne_points  9.684375         1.588472    0.034574  7.847693       77
#
#
# ---
# ---
# Segment 2011_09_28_drive_0021_sync
# Start 2011-09-28 12:39:24 	Duration 21.569384823 sec
# Num Images 209 (Lidars 209)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.648432         6.134509    0.027595  21.557907      209
# 1         image_01  9.648443         6.130049    0.026995  21.557883      209
# 2         image_02  9.648432         0.000000    0.000000  21.557906      209
# 3         image_03  9.648438         0.552978    0.060110  21.557894      209
# 4             oxts  9.646572         6.130452    2.876653  21.562064      209
# 5  velodyne_points  9.648421         1.513975    0.036878  21.557931      209
#
#
# ---
# ---
# Segment 2011_09_28_drive_0205_sync
# Start 2011-09-28 14:14:06 	Duration 3.516568672 sec
# Num Images 35 (Lidars 35)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.695158         6.134183    0.021873  3.506905       35
# 1         image_01  9.695158         6.132167    0.020741  3.506905       35
# 2         image_02  9.695179         0.000000    0.000000  3.506898       35
# 3         image_03  9.695497         0.556973    0.059465  3.506783       35
# 4             oxts  9.685749         6.065682    2.868067  3.510312       35
# 5  velodyne_points  9.695404         1.606716    0.028340  3.506816       35
#
#
# ---
# ---
# Segment 2011_09_26_drive_0060_sync
# Start 2011-09-26 14:34:42 	Duration 7.992836465000001 sec
# Num Images 78 (Lidars 78)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.656132         6.504875    0.690447  7.974208       78
# 1         image_01  9.655621         6.428208    0.697635  7.974629       78
# 2         image_02  9.655455         0.000000    0.000000  7.974767       78
# 3         image_03  9.655447         0.550078    0.064816  7.974773       78
# 4             oxts  9.648837         6.700128    3.053988  7.980237       78
# 5  velodyne_points  9.655441        10.456311    0.280008  7.974778       78
#
#
# ---
# ---
# Segment 2011_09_28_drive_0145_sync
# Start 2011-09-28 14:01:56 	Duration 3.6187768050000004 sec
# Num Images 36 (Lidars 36)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.693023         6.202413    0.174924  3.610845       36
# 1         image_01  9.693038         6.205221    0.167697  3.610839       36
# 2         image_02  9.693131         0.000000    0.000000  3.610804       36
# 3         image_03  9.693149         0.547840    0.065009  3.610798       36
# 4             oxts  9.694535         6.279826    2.830107  3.610281       36
# 5  velodyne_points  9.693264         1.607193    0.040462  3.610755       36
#
#
# ---
# ---
# Segment 2011_09_28_drive_0165_sync
# Start 2011-09-28 14:06:18 	Duration 8.466440171 sec
# Num Images 83 (Lidars 83)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.696279         6.141881    0.025241  8.456853       83
# 1         image_01  9.696328         6.136009    0.015792  8.456810       83
# 2         image_02  9.696274         0.000000    0.000000  8.456856       83
# 3         image_03  9.696274         0.556061    0.059648  8.456857       83
# 4             oxts  9.691711         6.139431    2.892437  8.460838       83
# 5  velodyne_points  9.696308         1.601854    0.038941  8.456827       83
# ---
# ---
# Segment 2011_09_28_drive_0087_sync
# Start 2011-09-28 13:32:28 	Duration 8.390746779 sec
# Num Images 82 (Lidars 82)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.666034         6.141381    0.009185  8.379859       82
# 1         image_01  9.666034         6.137293    0.004403  8.379859       82
# 2         image_02  9.666043         0.000000    0.000000  8.379851       82
# 3         image_03  9.666182         0.551142    0.059435  8.379730       82
# 4             oxts  9.664964         5.938728    2.882223  8.380786       82
# 5  velodyne_points  9.666080         1.578750    0.033370  8.379819       82
#
#
# ---
# ---
# Segment 2011_09_28_drive_0002_sync
# Start 2011-09-28 12:26:56 	Duration 38.889539688 sec
# Num Images 376 (Lidars 376)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.645428         6.138344    0.019915  38.878525      376
# 1         image_01  9.645427         6.134213    0.018395  38.878527      376
# 2         image_02  9.645428         0.000000    0.000000  38.878524      376
# 3         image_03  9.645458         0.550148    0.059705  38.878404      376
# 4             oxts  9.644150         6.143247    2.894329  38.883675      376
# 5  velodyne_points  9.645349         1.676740    0.113349  38.878844      376
#
#
# ---
# ---
# Segment 2011_09_26_drive_0117_sync
# Start 2011-09-26 15:40:43 	Duration 68.187700039 sec
# Num Images 660 (Lidars 660)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.667601         6.484387    0.718899  68.165824      660
# 1         image_01  9.667363         6.532249    0.756692  68.167506      660
# 2         image_02  9.667447         0.000000    0.000000  68.166911      660
# 3         image_03  9.667449         0.542572    0.068122  68.166899      660
# 4             oxts  9.666602         6.947912    3.646070  68.172873      660
# 5  velodyne_points  9.667453        10.498986    0.090170  68.166870      660
#
#
# ---
# ---
# Segment 2011_09_28_drive_0068_sync
# Start 2011-09-28 13:27:36 	Duration 6.836966938000001 sec
# Num Images 67 (Lidars 67)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.664599         6.239752    0.300446  6.829047       67
# 1         image_01  9.664604         6.223515    0.294330  6.829044       67
# 2         image_02  9.664590         0.000000    0.000000  6.829053       67
# 3         image_03  9.664578         0.548601    0.061897  6.829062       67
# 4             oxts  9.662353         6.117700    2.899484  6.830634       67
# 5  velodyne_points  9.664591         1.574712    0.041497  6.829052       67
#
#
# ---
# ---
# Segment 2011_09_26_drive_0035_sync
# Start 2011-09-26 14:01:22 	Duration 13.470546053000001 sec
# Num Images 131 (Lidars 131)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.662751         6.633631    0.976161  13.453725      131
# 1         image_01  9.662680         6.679717    1.012107  13.453825      131
# 2         image_02  9.662805         0.000000    0.000000  13.453650      131
# 3         image_03  9.662711         0.532321    0.066274  13.453782      131
# 4             oxts  9.664997         6.854692    2.967837  13.450599      131
# 5  velodyne_points  9.662809        10.472276    0.162847  13.453644      131
#
#
# ---
# ---
# Segment 2011_09_28_drive_0117_sync
# Start 2011-09-28 13:46:14 	Duration 3.6188501270000004 sec
# Num Images 36 (Lidars 36)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.690445         6.133371    0.027247  3.611805       36
# 1         image_01  9.690454         6.128682    0.028760  3.611802       36
# 2         image_02  9.690135         0.000000    0.000000  3.611921       36
# 3         image_03  9.690446         0.561847    0.058414  3.611805       36
# 4             oxts  9.694037         5.943629    2.809341  3.610467       36
# 5  velodyne_points  9.690317         1.597623    0.036969  3.611853       36
#
#
# ---
# ---
# Segment 2011_09_28_drive_0043_sync
# Start 2011-09-28 12:50:02 	Duration 14.928122368 sec
# Num Images 145 (Lidars 145)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.650586         6.137167    0.021490  14.921374      145
# 1         image_01  9.650585         6.133139    0.020846  14.921375      145
# 2         image_02  9.650587         0.000000    0.000000  14.921372      145
# 3         image_03  9.650581         0.553156    0.060916  14.921381      145
# 4             oxts  9.650505         6.046562    2.885492  14.921499      145
# 5  velodyne_points  9.650576         1.429714    0.036498  14.921388      145
#
#
# ---
# ---
# Segment 2011_09_26_drive_0011_sync
# Start 2011-09-26 13:10:04 	Duration 24.042591149000003 sec
# Num Images 233 (Lidars 233)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.656817         6.503260    0.802869  24.024480      233
# 1         image_01  9.656817         6.347090    0.577083  24.024479      233
# 2         image_02  9.656386         0.000000    0.000000  24.025553      233
# 3         image_03  9.656386         0.541326    0.066602  24.025552      233
# 4             oxts  9.658282         6.735201    3.016264  24.020834      233
# 5  velodyne_points  9.656404        10.519455    0.047849  24.025506      233
#
#
# ---
# ---
# Segment 2011_09_28_drive_0038_sync
# Start 2011-09-28 12:47:21 	Duration 11.304489570000001 sec
# Num Images 110 (Lidars 110)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.651506         6.141101    0.018714  11.293575      110
# 1         image_01  9.651506         6.136391    0.014736  11.293575      110
# 2         image_02  9.651506         0.000000    0.000000  11.293574      110
# 3         image_03  9.651506         0.541637    0.059228  11.293574      110
# 4             oxts  9.645131         6.109879    2.908246  11.301039      110
# 5  velodyne_points  9.651480         1.584571    0.038391  11.293604      110
#
#
# ---
# ---
# Segment 2011_09_26_drive_0059_sync
# Start 2011-09-26 14:33:49 	Duration 38.52740955 sec
# Num Images 373 (Lidars 373)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.660631         6.449112    0.648845  38.506800      373
# 1         image_01  9.660655         6.520289    0.817886  38.506707      373
# 2         image_02  9.660647         0.000000    0.000000  38.506738      373
# 3         image_03  9.660654         0.543903    0.065056  38.506710      373
# 4             oxts  9.659417         6.585228    3.328309  38.511641      373
# 5  velodyne_points  9.660645        10.512215    0.048935  38.506747      373
#
#
# ---
# ---
# Segment 2011_09_26_drive_0046_sync
# Start 2011-09-26 14:13:14 	Duration 12.831808016 sec
# Num Images 125 (Lidars 125)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.676141         6.484892    0.786633  12.815026      125
# 1         image_01  9.676094         6.606516    0.885438  12.815088      125
# 2         image_02  9.676098         0.000000    0.000000  12.815084      125
# 3         image_03  9.676036         0.540209    0.067314  12.815165      125
# 4             oxts  9.679363         6.565598    3.040689  12.810760      125
# 5  velodyne_points  9.676021        10.482931    0.107784  12.815185      125
#
#
# ---
# ---
# Segment 2011_09_26_drive_0019_sync
# Start 2011-09-26 13:14:14 	Duration 49.738229765 sec
# Num Images 481 (Lidars 481)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.654507         6.503357    0.730807  49.717712      481
# 1         image_01  9.654498         6.355636    0.582005  49.717758      481
# 2         image_02  9.654508         0.000000    0.000000  49.717707      481
# 3         image_03  9.654469         0.544872    0.110317  49.717910      481
# 4             oxts  9.653671         6.741295    3.067689  49.722018      481
# 5  velodyne_points  9.654509        10.522080    0.102227  49.717700      481
#
#
# ---
# ---
# Segment 2011_09_28_drive_0138_sync
# Start 2011-09-28 13:58:40 	Duration 6.923234717000001 sec
# Num Images 68 (Lidars 68)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.691954         6.138335    0.016694  6.912951       68
# 1         image_01  9.691988         6.134580    0.015271  6.912926       68
# 2         image_02  9.691976         0.000000    0.000000  6.912935       68
# 3         image_03  9.691808         0.553208    0.060113  6.913054       68
# 4             oxts  9.681195         6.088267    2.898712  6.920633       68
# 5  velodyne_points  9.691966         1.605318    0.032207  6.912942       68
#
#
# ---
# ---
# Segment 2011_09_28_drive_0066_sync
# Start 2011-09-28 13:23:18 	Duration 2.906996581 sec
# Num Images 29 (Lidars 29)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.660289         6.140224    0.009604  2.898464       29
# 1         image_01  9.660287         6.136458    0.004165  2.898465       29
# 2         image_02  9.660286         0.000000    0.000000  2.898465       29
# 3         image_03  9.660288         0.560711    0.060524  2.898464       29
# 4             oxts  9.655485         6.189355    2.876645  2.899906       29
# 5  velodyne_points  9.660346         1.573711    0.041263  2.898447       29
# ---
# ---
# Segment 2011_09_26_drive_0048_sync
# Start 2011-09-26 14:14:10 	Duration 2.1934633210000003 sec
# Num Images 22 (Lidars 22)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.677214         6.599340    1.025023  2.170046       22
# 1         image_01  9.670676         6.342953    0.643937  2.171513       22
# 2         image_02  9.670674         0.000000    0.000000  2.171514       22
# 3         image_03  9.670101         0.502695    0.058095  2.171642       22
# 4             oxts  9.676287         6.235816    3.182645  2.170254       22
# 5  velodyne_points  9.670562        10.502772    0.028223  2.171539       22
#
#
# ---
# ---
# Segment 2011_09_28_drive_0078_sync
# Start 2011-09-28 13:30:12 	Duration 3.732179968 sec
# Num Images 37 (Lidars 37)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.663385         6.230619    0.373261  3.725403       37
# 1         image_01  9.663447         6.224632    0.367393  3.725379       37
# 2         image_02  9.663297         0.000000    0.000000  3.725436       37
# ...
# Start 2011-09-28 14:12:18 	Duration 3.926827008 sec
# Num Images 39 (Lidars 39)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.693805         6.538464    0.987072  3.920029       39
# 1         image_01  9.693889         6.514494    0.966248  3.919996       39
# 2         image_02  9.693649         0.000000    0.000000  3.920092       39
# 3         image_03  9.693360         0.539792    0.068314  3.920209       39
# 4             oxts  9.692928         6.639089    3.050028  3.920384       39
# 5  velodyne_points  9.693472         1.631272    0.102667  3.920164       39
#
#
# ---
# ---
# Segment 2011_09_28_drive_0128_sync
# Start 2011-09-28 13:48:27 	Duration 2.89586304 sec
# Num Images 29 (Lidars 29)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.691129         6.180936    0.075673  2.889240       29
# 1         image_01  9.691057         6.169105    0.083152  2.889262       29
# 2         image_02  9.691207         0.000000    0.000000  2.889217       29
# 3         image_03  9.691200         0.548198    0.068669  2.889219       29
# 4             oxts  9.720677         6.096889    2.957712  2.880458       29
# 5  velodyne_points  9.691243         1.607418    0.043510  2.889206       29
#
#
# ---
# ---
# Segment 2011_09_26_drive_0023_sync
# Start 2011-09-26 13:17:59 	Duration 49.03902947300001 sec
# Num Images 474 (Lidars 474)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.649654         6.564947    0.869336  49.017302      474
# 1         image_01  9.649704         6.366847    0.713575  49.017047      474
# 2         image_02  9.649705         0.000000    0.000000  49.017045      474
# 3         image_03  9.649705         0.541672    0.068529  49.017045      474
# 4             oxts  9.648735         6.953367    3.127537  49.021968      474
# 5  velodyne_points  9.649702        10.506753    0.112922  49.017055      474
#
#
# ---
# ---
# Segment 2011_09_28_drive_0096_sync
# Start 2011-09-28 13:34:38 	Duration 4.555475519000001 sec
# Num Images 45 (Lidars 45)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.674134         6.162384    0.060589  4.548211       45
# 1         image_01  9.674061         6.156052    0.067838  4.548245       45
# 2         image_02  9.673992         0.000000    0.000000  4.548278       45
# 3         image_03  9.673712         0.551690    0.059158  4.548409       45
# 4             oxts  9.669292         7.156123    2.742892  4.550488       45
# 5  velodyne_points  9.673927         1.585478    0.035795  4.548308       45
#
#
# ---
# ---
# Segment 2011_09_28_drive_0110_sync
# Start 2011-09-28 13:44:25 	Duration 6.405114624 sec
# Num Images 63 (Lidars 63)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.689783         6.130525    0.030772  6.398492       63
# 1         image_01  9.689771         6.128425    0.030294  6.398500       63
# 2         image_02  9.689955         0.000000    0.000000  6.398378       63
# 3         image_03  9.689787         0.549101    0.060011  6.398489       63
# 4             oxts  9.686506         6.063181    2.874864  6.400657       63
# 5  velodyne_points  9.689857         1.601692    0.036169  6.398443       63
#
#
# ---
# ---
# Segment 2011_09_28_drive_0094_sync
# Start 2011-09-28 13:34:11 	Duration 8.796590347 sec
# Num Images 86 (Lidars 86)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.673634         6.237598    0.408553  8.786770       86
# 1         image_01  9.673642         6.228109    0.396807  8.786763       86
# 2         image_02  9.673626         0.000000    0.000000  8.786777       86
# 3         image_03  9.673495         0.533362    0.063078  8.786896       86
# 4             oxts  9.669125         6.504051    2.833048  8.790868       86
# 5  velodyne_points  9.673778         1.608688    0.070911  8.786639       86
#
#
# ---
# ---
# Segment 2011_09_26_drive_0029_sync
# Start 2011-09-26 13:24:51 	Duration 44.483001323 sec
# Num Images 430 (Lidars 430)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.648601         6.385804    0.595913  44.462406      430
# 1         image_01  9.647922         6.446081    0.670406  44.465536      430
# 2         image_02  9.648482         0.000000    0.000000  44.462955      430
# 3         image_03  9.648447         0.541083    0.065862  44.463116      430
# 4             oxts  9.648723         6.427007    2.947265  44.461842      430
# 5  velodyne_points  9.648469        10.510713    0.080939  44.463012      430
#
#
# ---
# ---
# Segment 2011_09_26_drive_0001_sync
# Start 2011-09-26 13:02:25 	Duration 11.053675927 sec
# Num Images 108 (Lidars 108)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.694589         6.421202    0.714301  11.037085      108
# 1         image_01  9.694810         6.419387    0.670247  11.036833      108
# 2         image_02  9.694812         0.000000    0.000000  11.036831      108
# 3         image_03  9.694815         0.554487    0.062264  11.036827      108
# 4             oxts  9.691620         6.601389    3.031787  11.040466      108
# 5  velodyne_points  9.694808        10.503917    0.041581  11.036836      108
#
#
# ---
# ---
# Segment 2011_09_26_drive_0017_sync
# Start 2011-09-26 13:13:08 	Duration 11.725092539 sec
# Num Images 114 (Lidars 114)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.653434         6.312019    0.478171  11.705679      114
# 1         image_01  9.651207         6.470013    0.684287  11.708380      114
# 2         image_02  9.651208         0.000000    0.000000  11.708379      114
# 3         image_03  9.651111         0.534353    0.064022  11.708497      114
# 4             oxts  9.657663         6.235953    2.926369  11.700553      114
# 5  velodyne_points  9.651144        10.513651    0.040327  11.708457      114
#
#
# ---
# ---
# Segment 2011_09_28_drive_0153_sync
# Start 2011-09-28 14:03:37 	Duration 9.190994855000001 sec
# Num Images 90 (Lidars 90)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.693460         6.137199    0.025184  9.181448       90
# 1         image_01  9.693468         6.132269    0.022939  9.181440       90
# 2         image_02  9.693485         0.000000    0.000000  9.181424       90
# 3         image_03  9.693598         0.540556    0.059416  9.181318       90
# 4             oxts  9.694075         6.155390    2.893830  9.180866       90
# 5  velodyne_points  9.693493         1.606936    0.034801  9.181417       90
#
#
# ---
# ---
# Segment 2011_09_26_drive_0101_sync
# Start 2011-09-26 15:26:02 	Duration 96.64487167700001 sec
# Num Images 936 (Lidars 936)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.676520         6.473468    0.680038  96.625644      936
# 1         image_01  9.676513         6.364213    0.574659  96.625718      936
# 2         image_02  9.676512         0.000000    0.000000  96.625728      936
# 3         image_03  9.676494         0.545882    0.107386  96.625908      936
# 4             oxts  9.676684         6.551811    3.005836  96.624007      936
# 5  velodyne_points  9.676504        10.500567    0.120557  96.625803      936
#
#
# ---
# ---
# Segment 2011_09_26_drive_0052_sync
# Start 2011-09-26 14:19:35 	Duration 7.990680341000001 sec
# Num Images 78 (Lidars 78)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.661184         6.365550    0.512196  7.970038       78
# 1         image_01  9.660741         6.679929    0.925857  7.970403       78
# 2         image_02  9.661064         0.000000    0.000000  7.970137       78
# 3         image_03  9.661225         0.550900    0.064092  7.970004       78
# 4             oxts  9.660867         6.398840    2.910423  7.970299       78
# 5  velodyne_points  9.661190        10.506049    0.076000  7.970033       78
#
#
# ---
# ---
# Segment 2011_09_26_drive_0079_sync
# Start 2011-09-26 14:58:03 	Duration 10.260414819000001 sec
# Num Images 100 (Lidars 100)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.664425         6.543732    0.707705  10.243754      100
# 1         image_01  9.664425         6.389215    0.656447  10.243755      100
# 2         image_02  9.664398         0.000000    0.000000  10.243783      100
# 3         image_03  9.664449         0.548365    0.072935  10.243729      100
# 4             oxts  9.667561         7.579212    4.304282  10.240432      100
# 5  velodyne_points  9.664456        10.517027    0.062794  10.243721      100
#
#
# ---
# ---
# Segment 2011_09_28_drive_0054_sync
# Start 2011-09-28 13:19:22 	Duration 4.567218919 sec
# Num Images 45 (Lidars 45)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.658581         6.130409    0.032714  4.555535       45
# 1         image_01  9.658584         6.128179    0.031895  4.555533       45
# 2         image_02  9.658574         0.000000    0.000000  4.555538       45
# 3         image_03  9.658314         0.559542    0.059214  4.555661       45
# 4             oxts  9.648245         6.134669    2.888825  4.560415       45
# 5  velodyne_points  9.658392         1.572540    0.035140  4.555624       45
#
#
# ---
# ---
# Segment 2011_09_26_drive_0086_sync
# Start 2011-09-26 15:05:33 	Duration 72.97369171300001 sec
# Num Images 706 (Lidars 706)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.663516         6.565735    0.896978  72.954814      706
# 1         image_01  9.663285         6.442426    0.807773  72.956558      706
# 2         image_02  9.663530         0.000000    0.000000  72.954709      706
# 3         image_03  9.663513         0.543933    0.146511  72.954834      706
# 4             oxts  9.663735         6.703302    3.155411  72.953159      706
# 5  velodyne_points  9.663515        10.506176    0.166532  72.954823      706
#
#
# ---
# ---
# Segment 2011_09_26_drive_0106_sync
# Start 2011-09-26 15:31:58 	Duration 23.404766395000003 sec
# Num Images 227 (Lidars 227)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.663027         6.541334    0.779462  23.388117      227
# 1         image_01  9.664276         6.493520    0.741423  23.385093      227
# 2         image_02  9.664257         0.000000    0.000000  23.385139      227
# 3         image_03  9.664257         0.542757    0.064130  23.385139      227
# 4             oxts  9.661950         6.456914    3.019426  23.390723      227
# 5  velodyne_points  9.664261        10.489398    0.149409  23.385130      227
#
#
# ---
# ---
# Segment 2011_09_28_drive_0039_sync
# Start 2011-09-28 12:47:54 	Duration 36.380378624 sec
# Num Images 352 (Lidars 352)
#             Series   Freq Hz  Diff img (msec)  std (msec)   Duration  Support
# 0         image_00  9.649824         6.158629    0.101933  36.373721      352
# 1         image_01  9.649833         6.153288    0.095073  36.373685      352
# 2         image_02  9.649814         0.000000    0.000000  36.373757      352
# 3         image_03  9.649845         0.544815    0.060122  36.373640      352
# 4             oxts  9.649858         6.094124    2.887057  36.373594      352
# 5  velodyne_points  9.649808         1.428250    0.109555  36.373780      352
#
#
# ---
# ---
# Segment 2011_09_26_drive_0002_sync
# Start 2011-09-26 13:02:44 	Duration 7.858233088 sec
# Num Images 77 (Lidars 77)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.692478         6.865436    1.144710  7.841132       77
# 1         image_01  9.693557         6.342374    0.554350  7.840259       77
# 2         image_02  9.692473         0.000000    0.000000  7.841136       77
# 3         image_03  9.692251         0.542062    0.069446  7.841316       77
# 4             oxts  9.693193         7.000496    3.365881  7.840554       77
# 5  velodyne_points  9.692383        10.509466    0.045673  7.841209       77
#
#
# ---
# ---
# Segment 2011_09_28_drive_0132_sync
# Start 2011-09-28 13:49:18 	Duration 7.441996313000001 sec
# Num Images 73 (Lidars 73)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.688004         6.139050    0.016942  7.431871       73
# 1         image_01  9.688006         6.134797    0.014963  7.431870       73
# 2         image_02  9.687985         0.000000    0.000000  7.431886       73
# 3         image_03  9.687848         0.555519    0.059982  7.431991       73
# 4             oxts  9.689520         6.175639    2.908302  7.430709       73
# 5  velodyne_points  9.687929         1.596706    0.037054  7.431929       73
#
#
# ---
# ---
# Segment 2011_09_28_drive_0171_sync
# Start 2011-09-28 14:07:54 	Duration 2.791449344 sec
# Num Images 28 (Lidars 28)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.695926         6.139278    0.026046  2.784675       28
# 1         image_01  9.696007         6.135140    0.025486  2.784652       28
# 2         image_02  9.695823         0.000000    0.000000  2.784704       28
# 3         image_03  9.695406         0.583495    0.049068  2.784824       28
# 4             oxts  9.711206         5.943392    2.762203  2.780293       28
# 5  velodyne_points  9.695695         1.592525    0.035552  2.784741       28
#
#
# ---
# ---
# Segment 2011_09_28_drive_0113_sync
# Start 2011-09-28 13:45:18 	Duration 7.541485591000001 sec
# Num Images 74 (Lidars 74)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.689555         6.133879    0.028285  7.533885       74
# 1         image_01  9.689555         6.130006    0.030426  7.533885       74
# 2         image_02  9.689707         0.000000    0.000000  7.533767       74
# 3         image_03  9.689557         0.554352    0.059508  7.533884       74
# 4             oxts  9.693590         6.076123    2.882935  7.530749       74
# 5  velodyne_points  9.689583         1.599744    0.034992  7.533864       74
# ---
# ---
# Segment 2011_09_28_drive_0177_sync
# Start 2011-09-28 14:08:54 	Duration 7.950938682 sec
# Num Images 78 (Lidars 78)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.692790         6.140370    0.014802  7.944049       78
# 1         image_01  9.692790         6.134250    0.014545  7.944049       78
# 2         image_02  9.692785         0.000000    0.000000  7.944053       78
# 3         image_03  9.692640         0.548467    0.059956  7.944172       78
# 4             oxts  9.696876         6.153629    2.883202  7.940702       78
# 5  velodyne_points  9.692684         1.607143    0.034620  7.944136       78
#
#
# ---
# ---
# Segment 2011_09_28_drive_0122_sync
# Start 2011-09-28 13:47:21 	Duration 4.345460211000001 sec
# Num Images 43 (Lidars 43)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.689967         6.134022    0.027964  4.334380       43
# 1         image_01  9.689964         6.130939    0.027160  4.334382       43
# 2         image_02  9.689956         0.000000    0.000000  4.334385       43
# 3         image_03  9.689960         0.549660    0.060782  4.334383       43
# 4             oxts  9.676100         6.215894    2.898102  4.340592       43
# 5  velodyne_points  9.689973         1.597393    0.033849  4.334377       43
#
#
# ---
# ---
# Segment 2011_09_28_drive_0136_sync
# Start 2011-09-28 13:50:12 	Duration 3.1031011840000002 sec
# Num Images 31 (Lidars 31)
#             Series   Freq Hz  Diff img (msec)  std (msec)  Duration  Support
# 0         image_00  9.688825         6.147046    0.043508  3.096351       31
# 1         image_01  9.688832         6.140778    0.036482  3.096349       31
# 2         image_02  9.688423         0.000000    0.000000  3.096479       31
# 3         image_03  9.688348         0.558207    0.059037  3.096503       31
# 4             oxts  9.709136         5.961680    2.846286  3.089873       31
# 5  velodyne_points  9.688501         1.589006    0.037572  3.096454       31

# %% [markdown]
# # Benchmark to Raw Mapping
# We now aggregate most of the data explored in this notebook in order to produce a final table asset useful for `avsegs` and other projects.  In particular, we produce a table that helps map Benchmark assets to Raw Sync data assets.

# %%
bench_to_raw_df = spark.sql("""
    WITH
      bench_to_raw AS (
          SELECT
            b.digest AS b_digest,
            r.digest AS r_digest,
            b.archive_name AS benchmark,
            r.category AS segment_category,
            b.filename AS b_filename,
            r.filename AS r_filename,
            b.split AS split
          FROM
            benchmark_df_with_split b FULL OUTER JOIN
            raw_data_df_with_category r ON b.digest = r.digest )
    
    SELECT *
    FROM
      bench_to_raw br FULL OUTER JOIN topic_time_df ttdf
      ON br.r_filename = ttdf.filename
        
    
    """)

# Reduce cardinality for faster I/O
bench_to_raw_df = bench_to_raw_df.repartition(20)

# We want to save as parquet.  When Pandas / pyarrow reads numeric columns that have nulls, 
# Pandas casts to float, which is really NOT what we want for timestamps (and other cols)
COLS_DEFAULT_ZERO = ('nanostamp', 'frame')
for col in COLS_DEFAULT_ZERO:
    bench_to_raw_df = bench_to_raw_df.withColumn(
                        col,
                        F.when(bench_to_raw_df[col].isNull(), 0).otherwise(bench_to_raw_df[col]))

# %%
# Sanity Check
bench_to_raw_df.limit(50).toPandas()
# Out:
#                                     b_digest  \
# 0                                       None
# 1   befdaae80adbb863093db4b1ff255f863584b6c4
# 2                                       None
# 3                                       None
# 4   750243d3ca3b6e063c6339975ec3cc42a64414b4
# 5   675eddc56c291e553e2cb1090aa9bf813032c777
# 6   971bb49ab0ba7dde4f0ef83f67fa794e15df5fab
# 7   7a9a3537cd4d22324bf7545433b7e94b40f741e3
# 8                                       None
# 9   d43e12a724baec56b3b3fa8695f97b0e9ecdd004
# 10                                      None
# 11  1c6c33bfa43d714730d76add02ba88ee3c823aba
# 12                                      None
# 13                                      None
# 14                                      None
# 15                                      None
# 16                                      None
# 17  67d35b790c6106000f3eb2b4c9850d949b98f8ea
# 18                                      None
# 19                                      None
# 20                                      None
# 21  222158fa1e547f0dbb57eef52c07e20d0ec54dec
# 22                                      None
# 23                                      None
# 24                                      None
# 25                                      None
# 26  f966ec47d28b64f1f7a0b5d57802f1aebdff5244
# 27                                      None
# 28  461599bbbc6f2337885faac9728932f377549053
# 29                                      None
# 30                                      None
# 31                                      None
# 32                                      None
# 33  20422920dfb3228a8145883876f7274390ca3142
# 34                                      None
# 35  c025a6906a560c9369f3b52e323e2da13f69f57f
# 36  806eb3664c761d467d30441587e4ae97ba528f12
# 37                                      None
# 38                                      None
# 39  ba8019ed06434dcdce667c81eca63274cfbb45ab
# 40                                      None
# 41  7017c8daf86b9216b82ac35b52cba7cc7afe06b0
# 42                                      None
# 43                                      None
# 44                                      None
# 45  18a2bc97b51e75411c67e5a8163451652b451b5b
# 46                                      None
# 47                                      None
# 48                                      None
# 49  7aaa1537c7d088caa2dc301e5ce151183f8c705d
#
#                                     r_digest                   benchmark  \
# 0   71c5f62767ea9164e1598c93d08491520bc1c809                        None
# 1   befdaae80adbb863093db4b1ff255f863584b6c4      data_object_prev_2.zip
# 2   2cfeeb792b9dc613c2b44e47a5e7a51cdbcf100a                        None
# 3   aa0f95675666d1edfe010ec1c24af1da3d0da2b5                        None
# 4   750243d3ca3b6e063c6339975ec3cc42a64414b4      data_object_prev_2.zip
# 5   675eddc56c291e553e2cb1090aa9bf813032c777      data_object_prev_2.zip
# 6   971bb49ab0ba7dde4f0ef83f67fa794e15df5fab    data_object_velodyne.zip
# 7   7a9a3537cd4d22324bf7545433b7e94b40f741e3   data_tracking_image_2.zip
# 8   a7f33be4f9b888928dcf8d5c41b6d1c1df36a312                        None
# 9   d43e12a724baec56b3b3fa8695f97b0e9ecdd004      data_object_prev_2.zip
# 10  fdc98f1ba343a91ac4947319a65cff6a7b65958f                        None
# 11  1c6c33bfa43d714730d76add02ba88ee3c823aba   data_tracking_image_2.zip
# 12  2b806cce28b9fcf022b04168511719ad3c8551b0                        None
# 13  b747a797d5f8d06c28715b3026acfd452ce899e9                        None
# 14  8d8835a39a2da7d254708b52334973bf023f2665                        None
# 15  9ac51c5cf34c0e3c3efce0c98916ed421f7dac12                        None
# 16  c27a9bdc2b0aa807075e251d19f8ae867ddfd42c                        None
# 17  67d35b790c6106000f3eb2b4c9850d949b98f8ea      data_object_prev_2.zip
# 18  9a028b5df2a98e7d12fac7fae792c1927c705b16                        None
# 19  d52b07a2020acfbc495a27ef000f40e691b1bc50                        None
# 20  15c139fb1f0e295644e31d67b7e88a3d6b3d9b08                        None
# 21  222158fa1e547f0dbb57eef52c07e20d0ec54dec   data_tracking_image_3.zip
# 22  da9f38acfffcb31cac7f60f06d62aa5264081495                        None
# 23  02d6a5e25f5752ae48999e21361bfb4b0770ffa7                        None
# 24  324049d7100d7c1461d38ec37a534d0835b8cea2                        None
# 25  e9c15c3d6b562059e040d3acc60d03edea9e186b                        None
# 26  f966ec47d28b64f1f7a0b5d57802f1aebdff5244  data_tracking_velodyne.zip
# 27  1d56ef1df07575cd33fc6e0099e8abc6284fe133                        None
# 28  461599bbbc6f2337885faac9728932f377549053      data_object_prev_2.zip
# 29  f1da9bc01957f13ea425439b7cd2b1c5bbd5378a                        None
# 30  bc906eac81d3632c97b9cfe5bd9058d9386c04fd                        None
# 31  3fc7cbbb0f4007b0ddcc59f2fcbbc8567c6f5083                        None
# 32  97703d4d86bbd730a0578c6a4272d5ae50b54b91                        None
# 33  20422920dfb3228a8145883876f7274390ca3142  data_tracking_velodyne.zip
# 34  c065adb068edf3558401edf68cbf385e7ab1defd                        None
# 35  c025a6906a560c9369f3b52e323e2da13f69f57f     data_object_image_3.zip
# 36  806eb3664c761d467d30441587e4ae97ba528f12      data_object_prev_2.zip
# 37  146bbd06dca6d005e33374919d99dcc6ee2a84ea                        None
# 38  2ac4c1635b013b80e430c3112d831056aed9763a                        None
# 39  ba8019ed06434dcdce667c81eca63274cfbb45ab   data_tracking_image_3.zip
# 40  1e4ee5d2a386baa0315e9e50a8484feaad6dacb3                        None
# 41  7017c8daf86b9216b82ac35b52cba7cc7afe06b0      data_object_prev_2.zip
# 42  849f9dc6c1d3afd9db2b65d33e0c723f9d199c69                        None
# 43  ddecec87382fa6eff3bb812bcd2e345b0f5252c4                        None
# 44  0801666a4c9aeae57a6884bb9eb3072dc94489d3                        None
# 45  18a2bc97b51e75411c67e5a8163451652b451b5b      data_object_prev_2.zip
# 46  413a0e054009c30e464f15c0bf0f1afb9840ff57                        None
# 47  4887035ad60038ae4419ef5686d7e1690c90b014                        None
# 48  c3e051bdd513ad0b55af15f9ea15271db0049d7f                        None
# 49  7aaa1537c7d088caa2dc301e5ce151183f8c705d   data_tracking_image_3.zip
#
#    segment_category                         b_filename  \
# 0       residential                               None
# 1            person      training/prev_2/003675_03.png
# 2              city                               None
# 3       residential                               None
# 4              city      training/prev_2/005376_03.png
# 5              city      training/prev_2/001241_03.png
# 6            person       training/velodyne/007372.bin
# 7              city  training/image_02/0001/000434.png
# 8       residential                               None
# 9              road      training/prev_2/005949_03.png
# 10      residential                               None
# 11      residential  training/image_02/0009/000252.png
# 12      residential                               None
# 13             city                               None
# 14      residential                               None
# 15      residential                               None
# 16      residential                               None
# 17             city      training/prev_2/004330_03.png
# 18      residential                               None
# 19      residential                               None
# 20      residential                               None
# 21             city  training/image_03/0019/000506.png
# 22      residential                               None
# 23      residential                               None
# 24      residential                               None
# 25      residential                               None
# 26             road  training/velodyne/0020/000486.bin
# 27             road                               None
# 28      residential      training/prev_2/005531_02.png
# 29             city                               None
# 30      residential                               None
# 31      residential                               None
# 32      residential                               None
# 33             city  training/velodyne/0019/000082.bin
# 34      residential                               None
# 35           person        training/image_3/001279.png
# 36             city      training/prev_2/005490_02.png
# 37      residential                               None
# 38      residential                               None
# 39             city  training/image_03/0011/000306.png
# 40      residential                               None
# 41           campus      training/prev_2/004924_01.png
# 42      residential                               None
# 43      residential                               None
# 44           campus                               None
# 45             city      training/prev_2/004119_03.png
# 46      residential                               None
# 47      residential                               None
# 48      residential                               None
# 49      residential  training/image_03/0009/000034.png
#
#                                            r_filename  split  \
# 0   2011_09_30/2011_09_30_drive_0020_sync/oxts/dat...   None
# 33  1317304508507383680  2011_09_29_drive_0071_sync  velodyne_points
# 34  1317386821265758660  2011_09_30_drive_0028_sync             oxts
# 35  1317217606323750144  2011_09_28_drive_0119_sync         image_03
# 36  1317051703536078848  2011_09_26_drive_0117_sync         image_02
# 37  1317646652183601345  2011_10_03_drive_0027_sync  velodyne_points
# 38  1317383890115661312  2011_09_30_drive_0018_sync         image_03
# 39  1317047661172268032  2011_09_26_drive_0059_sync         image_03
# 40  1317383784798914048  2011_09_30_drive_0018_sync         image_02
# 41  1317214083982796032  2011_09_28_drive_0039_sync         image_02
# 42  1317388408250346534  2011_09_30_drive_0033_sync  velodyne_points
# 43  1317387011452107234  2011_09_30_drive_0028_sync             oxts
# 44  1317214208336896000  2011_09_28_drive_0043_sync         image_01
# 45  1317042540884364288  2011_09_26_drive_0009_sync         image_02
# 46  1317650591184142592  2011_10_03_drive_0034_sync         image_00
# 47  1317387078152570112  2011_09_30_drive_0028_sync         image_02
# 48  1317386889229821952  2011_09_30_drive_0028_sync         image_01
# 49  1317045745984118784  2011_09_26_drive_0036_sync         image_03

# %%
if not os.path.exists(BENCH_TO_RAW_DF_PATH):
    bench_to_raw_df.write.parquet(BENCH_TO_RAW_DF_PATH, compression='gzip')

# %% [markdown]
# # Misc

# %%
# Tool for extracting segment names from KITTI website
# http://www.cvlibs.net/datasets/kitti/raw_data.php
# Example extracted from calibration page
page_raw_text = """Data Category: Calibration
Before browsing, please wait some moments until this page is fully loaded.
2011_09_26_drive_0119 (0.1 GB)
Length: 17 frames (00:01 minutes)
Image resolution: 1392 x 512 pixels
Labels: 0 Cars, 0 Vans, 0 Trucks, 0 Pedestrians, 0 Sitters, 0 Cyclists, 0 Trams, 0 Misc
Downloads: [unsynced+unrectified data]
2011_09_28_drive_0225 (0.1 GB)
Length: 19 frames (00:01 minutes)
Image resolution: 1392 x 512 pixels
Labels: 0 Cars, 0 Vans, 0 Trucks, 0 Pedestrians, 0 Sitters, 0 Cyclists, 0 Trams, 0 Misc
Downloads: [unsynced+unrectified data]
2011_09_29_drive_0108 (0.1 GB)
Length: 20 frames (00:02 minutes)
Image resolution: 1392 x 512 pixels
Labels: 0 Cars, 0 Vans, 0 Trucks, 0 Pedestrians, 0 Sitters, 0 Cyclists, 0 Trams, 0 Misc
Downloads: [unsynced+unrectified data]
2011_09_30_drive_0072 (0.0 GB)
Length: 11 frames (00:01 minutes)
Image resolution: 1392 x 512 pixels
Labels: 0 Cars, 0 Vans, 0 Trucks, 0 Pedestrians, 0 Sitters, 0 Cyclists, 0 Trams, 0 Misc
Downloads: [unsynced+unrectified data]
2011_10_03_drive_0058 (0.1 GB)
Length: 35 frames (00:03 minutes)
Image resolution: 1392 x 512 pixels
Labels: 0 Cars, 0 Vans, 0 Trucks, 0 Pedestrians, 0 Sitters, 0 Cyclists, 0 Trams, 0 Misc
Downloads: [unsynced+unrectified data]"""

import re
import pprint
pprint.pprint(sorted(re.findall('\d\d\d\d_\d\d_\d\d_drive_\d\d\d\d', page_raw_text)))
